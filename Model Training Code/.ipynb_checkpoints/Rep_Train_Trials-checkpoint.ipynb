# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import argparse
import csv
import os
import sys
import re
import argparse
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from scipy.stats import loguniform
from scipy.io import loadmat
from sklearn import metrics
from torch.utils import data

sys.path.append('/content/drive/MyDrive/Tesi_Magistrale')

# %%
from Data_Processing_Utils import Norm_each_sub_by_own_param,NormalizeData, train_val_test_split_df, PlotLoss, plot_confusion_matrix, \
    Get_Sub_Norm_params, windowing_Dataframe

from DATALOADERS import dataframe_dataset_triplet, Pandas_Dataset

from MODELS import MKCNN, MKCNN_grid, random_choice, train_model_triplet, pre_train_model_triplet, train_model_standard, MultiKernelConv2D_grid

# %%
def Norm_wnd_each_sub_by_own_param(df, mode='sub', norm_type: str = None,
                               rectify=False):
    norm_df = pd.DataFrame()
    n_sub = np.unique(df['sub'])
    sub_grouped = df.groupby('sub')
    chs = [col for col in df.columns if 'ch' in col]
    sample_idxs = np.unique(df['sample_index'])
    tot_idxs = len(sample_idxs)
    print("Starting Window Normalization")
    for idx in sample_idxs:
        # estraggo finestra con indice idx
        data_wnd = df[df['sample_index']==idx]
        # estraggo solo i dati emg
        data_to_norm = data_wnd.filter(like='ch', axis=1)
        if mode == 'sub':
            # normalizzo tutta la finestra
            normed_data_wnd = NormalizeData(data_to_norm,norm_type=norm_type)
            data_wnd.loc[normed_data_wnd.index, chs] = normed_data_wnd
        elif mode == 'channel':
            # normalizzo ogni canale singolarmente
            normed_data_wnd = data_to_norm.copy()
            for j in data_to_norm.columns:
                normed_data_wnd[j] = NormalizeData(normed_data_wnd[j], norm_type=norm_type)
                data_wnd.loc[normed_data_wnd.index, j] = normed_data_wnd
        norm_df = pd.concat([norm_df, data_wnd], axis=0, ignore_index = True)
        print(f"Normalizing... [{'#'*int(20*idx/tot_idxs)}{'-'*int(21*(1-idx/tot_idxs))}] {int(idx/tot_idxs*100)}% Compleated ", end='\r')
    print("\nDone!")

    if 'Unanmed: 0' in norm_df.columns:
        norm_df.drop('Unnamed: 0',axis=1, inplace=True)
    return norm_df

def make_merged_df(dfs_path: str, wnd_list: list, save = True, save_path: str = None):
    """
    dfs_path: folder where the windowed dataframes are stored
    wnd_list: list with the name of the windowed dfs to merge
    """
    print("Merging Dataframes...")
    #wnd_list = [x for x in sorted(os.listdir(dfs_path)) if name in x]
    dfs = []
    prev_df_lenghts = 0
    i = 0
    # loop to merge all the windowed dataframes into one, while changing the sample_index accordingly
    for dataframe in wnd_list:
        df = pd.read_csv(dfs_path+dataframe)
        df['sample_index'] = df['sample_index'] + prev_df_lenghts +1*(i>0)
        dfs.append(df)
        prev_df_lenghts = df['sample_index'].iloc[-1]
        i+=1

    total_df = pd.concat(dfs, ignore_index = True)
    #print(total_df.shape)
    total_df_chs = [col for col in total_df.columns if 'Ch' in col]
    total_df[total_df_chs] = total_df[total_df_chs].astype(np.uint16)
    total_df['angle'] = total_df['angle'].astype(np.int16)
    if save:
        if not os.path.exists(save_path):
          os.makedirs(save_path)
        save_directory = (dfs_path + '/angle_merged/' if save_path == None else save_path) + 'merged_dataframe_wnd_200.csv'
        total_df.to_csv(save_directory, index = False)
        print("\nMerged dataframe saved at ----> "+ save_directory+"\n")
    return total_df

# %%
file_path = '/content/drive/MyDrive/Tesi_Magistrale'
data_path = '/content/drive/MyDrive/Tesi_Magistrale/DATA'
subj = 'Giulio'
day = 1
database = data_path+f'/{subj}_offset_relabel/day{day}/mat/'
save_path_base = data_path+f'/{subj}_offset_relabel/day{day}/Rep_Train_Trials/'

# %%
# Directory and data creation
os.chdir(database)
EMG_data = [x for x in sorted(os.listdir(database)) if subj in x]
print('Files found:')
for file in EMG_data:
    print(file)
WND_LEN = 200
n_channels = 8
columns = [f'Ch{ch}' for ch in range(1, n_channels+1)]
# Out:
# Files found:
# Giulio_6rep_5sec_angle_1_ESP32_1000Hz_relabel.mat
# Giulio_6rep_5sec_angle_2_ESP32_1000Hz_relabel.mat
# Giulio_6rep_5sec_angle_3_ESP32_1000Hz_relabel.mat
# Giulio_6rep_5sec_angle_4_ESP32_1000Hz_relabel.mat
# Giulio_6rep_5sec_angle_5_ESP32_1000Hz_relabel.mat

# %%
single_model = False # only one model or one model per angle?
merged = False # multiple days or signle day?
save_test_set = False
day = 1
NORM_MODE = 'sub'
NORM_TYPE = 'zero_to_one'
NORM_WND = False
RECT = True
train_val_test_rep_combo = [[[1], [5, 6], [2]],
                            [[1, 2], [5, 6], [3]]
                            ,[[1, 2, 3], [5, 6], [4]]]

print(f"Merged: {merged}, Single model: {single_model}")
# Out:
# Merged: False, Single model: False

# %%
for train_val_test_rep in train_val_test_rep_combo:
    test_rep = train_val_test_rep[[2][0]]
    print(f"Test Rep {test_rep}")
    if len(train_val_test_rep[0])==1:
        save_path = save_path_base + '/Rep_1/'
    elif len(train_val_test_rep[0])==2:
        save_path = save_path_base + '/Rep_1_2/'
    elif len(train_val_test_rep[0])==3:
        save_path = save_path_base + '/Rep_1_2_3/'
    if single_model:
        if merged:
            database = data_path + f'/{subj}_offset_relabel/merged_day1_2/'
            name = f'angle_merged/merged_dataframe_wnd_{WND_LEN}.csv'
        else:
            database = data_path + f'/{subj}_offset_relabel/day{day}/'
            name = f'Dataframe/angle_merged/merged_dataframe_wnd_{WND_LEN}.csv'

        df = pd.read_csv(database + name,
                                    dtype={'sub': np.int8, 'label': np.int8, 'rep': np.int8, 'sample_index': np.uint32})
        n_channels = [cx for cx in df.columns if 'ch' in cx]
        df.loc[:, n_channels] = df.loc[:, n_channels].astype(np.float32)
        exe_labels = ['medium_wrap', 'lateral', 'power_sphere', 'power_disk', 'prismatic_pinch', 'index_extension',
                        'wave_out', 'wave_in', 'fist', 'open_hand']
        device = torch.device('cuda')

        print("Normalization process initiated")
        if NORM_WND:
            df = Norm_wnd_each_sub_by_own_param(df, mode= NORM_MODE, norm_type= NORM_TYPE, rectify=RECT )
            #df.to_csv(merge_path + f"wnd_norm_merged_dataframe_{WND_LEN}.csv")
        else:
            df = Norm_each_sub_by_own_param(df, mode= NORM_MODE, norm_type= NORM_TYPE, rectify=RECT )
            #df.to_csv(merge_path + f"norm_merged_dataframe_{WND_LEN}.csv")

        # since we need to balance the dataframe with reps from each angle, we need to now the angle index
        # I added that column with this code

        minAngle, maxAngle = df['angle'].abs().min(), df['angle'].abs().max()
        print(f"minAngle: {minAngle} maxAngle: {maxAngle}")
        angleRange = maxAngle - minAngle
        interval = 5*round(angleRange * 0.125/5) #round interval to the closest multiple of 5
        residue = angleRange-interval*8
        intervals = [abs(minAngle+interval), abs(minAngle+interval*3), abs(maxAngle-interval*3), abs(maxAngle-interval)]
        print(f"Angle Intervals: {intervals}")

        angle_index = []
        for ang in df['angle']:
            ang = abs(ang)
            if ang < intervals[0]:
                angle_index.append(1)
            elif ang < intervals[1]:
                angle_index.append(2)
            elif ang < intervals[2]:
                angle_index.append(3)
            elif ang < intervals[3]:
                angle_index.append(4)
            else:
                angle_index.append(5)

        if 'Unnamed: 0' in df.columns:
            df.drop('Unnamed: 0', axis = 1, inplace =True)
        df["angle_index"] = angle_index
        df["angle_index"] = df["angle_index"].astype(np.int8)
        # df now has a column keeping track of which file the data comes from

        # need to figure out how to pick certain reps from ceratin angles

        angle_index = [1,2,3,4,5] # index values for the angle
        rep_index = [1,2,3,4,5,6] # index values for the reps
        # problem_ figure out a way to compose a dataframe for the model
        # that includes reps from each angle and has the same length as
        # the dataframes the other models are using

        # the models have each a dataframe of 60 reps divided in 10 poses
        # This then get split in:
        # - a training set 30 reps long
        # - a validation set 20 reps long
        # - a test set 10 reps long

        # the single model has a dataframe compose of the concatenation
        # of the dataframes for each angle, that has 300 total reps available.
        # I need to shink it to a 60 rep dataframe before splitting it

        # Notice: if we are training the models on a dataframe composed of
        # multiple days we need do multiply the total number of poses by the number of days

        #

        # %% From here is the same code as for the multiple models training

        df.drop(['angle_index'],axis=1, inplace = True)
        print(df.shape)

        split_mode = 'rep'
        df_train, df_val, df_test = train_val_test_split_df(df, mode=split_mode, manual_sel=train_val_test_rep)

        # Saving val and test rep used
        valid_group = np.unique(df_val[split_mode])
        test_group = np.unique(df_test[split_mode])[0]
        # %% pandas dataset
        # You must pass to the dataloader a groupby dataframe
        train_set = Pandas_Dataset(df_train.groupby('sample_index'))
        valid_set = Pandas_Dataset(df_val.groupby('sample_index'))
        test_set = Pandas_Dataset(df_test.groupby('sample_index'))
        df_test.set_index('sample_index', inplace = True)
        if save_test_set:
            print("Saving test set...")
            path_to_save = database + f"test_rep{test_rep}/test_sets/"
            if not os.path.exists(path_to_save):
                os.makedirs(path_to_save)
            df_test.to_csv(path_to_save+"test_set_single_model_merged.csv") if merged else df_test.to_csv(path_to_save+f"test_set_single_model_day_{day}.csv")
            print("Test set saved")

        # %% Dataloaders
        batch_size = 32
        num_workers = 0
        params = {'batch_size': batch_size,
                'shuffle': True,
                # 'sampler': sampler,
                'num_workers': num_workers,
                'drop_last': False}

        train_set_generator = data.DataLoader(train_set, **params)
        valid_set_generator = data.DataLoader(valid_set, **params)
        test_set_generator = data.DataLoader(test_set, **params)

        #%% Parametric model
        kernels_gap = [g for g in range(0, 3 * round(WND_LEN / 20), round(WND_LEN / 20))]
        kernel_sizes = np.full((3, 5, 2), [1, 3])
        for j in range(3):
            for i in range(5):
                kernel_sizes[j][i][0] = (round(WND_LEN / 20) * (i + 1) + kernels_gap[j])

        n_classes = 10

        net = {'N_multik': 32, 'N_Conv_conc': 64, 'N_SepConv': 128,
        'Kernel_multi_dim': kernel_sizes[0],
        'Kernel_Conv_conc': 1,
        'act_func': nn.ReLU(),
        'Pool_Type': nn.MaxPool2d,
        'wnd_len':WND_LEN
        }

        model = MKCNN_grid(net, num_classes=n_classes)
        model = model.to(device)

        #%% Loss Optim and scheduler
        # Define Loss functions
        cross_entropy_loss = nn.CrossEntropyLoss(reduction='mean').to(device)
        # triplet = nn.TripletMarginLoss(reduction='mean', margin=1, p=2)

        # Define Optimizer
        learning_rate = 0.0001
        # changed beta values from (0.5,0.999) to (0.9,0.999)
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), weight_decay=1e-4)

        # # Define Scheduler
        precision = 1e-6
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, factor=.2,
                                                            patience=5, verbose=True, eps=precision)

        print(f'Model created with Num params: {sum([p.numel() for p in model.parameters() if p.requires_grad])}')


        # %% Traning model
        # if it doesn't work check if I left the angle in the Pandas_Dataset class
        best_weights, tr_losses, val_losses = train_model_standard(model=model, loss_fun=cross_entropy_loss,
                                                                optimizer=optimizer, scheduler=scheduler,
                                                                dataloaders={"train": train_set_generator,
                                                                                "val": valid_set_generator},
                                                                num_epochs=50, precision=precision,
                                                                patience=10, patience_increase=5)

    #%% Saving
        database = save_path
        if merged:
            filename = f'wnd_{WND_LEN}_{NORM_TYPE}_{NORM_MODE}_rect_{RECT}_single_model_merged'
        else:
            filename = f'wnd_{WND_LEN}_{NORM_TYPE}_{NORM_MODE}_rect_{RECT}_single_model_day{day}'
        # Save state dict of the model
        if not os.path.exists(database + f'Cross_{split_mode}/Best_States/'):
            os.makedirs(database + f'Cross_{split_mode}/Best_States/')
        torch.save(best_weights['state_dict'],
                database + f'Cross_{split_mode}/Best_States/state_dict_{filename}.pth')

        # %% PlotLoss
        if not os.path.exists(database + f'Cross_{split_mode}/Plot/'):
            os.makedirs(database + f'Cross_{split_mode}/Plot/')

        PlotLoss(tr_losses, val_loss=val_losses,
                title=f'Cross-{split_mode}',
                path_to_save=database + f'Cross_{split_mode}/Plot/',
                filename=f'Cross_{split_mode}_{filename}.png')

        # %% Conf Matrix
        if not os.path.exists(database + f'Cross_{split_mode}/Conf_Matrix/'):
            os.makedirs(database + f'Cross_{split_mode}/Conf_Matrix/')

        # Evaluation
        softmax_block = nn.Softmax(dim=1)
        y_true = []
        y_pred = []

        test_dataloader = test_set_generator
        net = model
        # Load Weights
        net.load_state_dict(torch.load(database + f'Cross_{split_mode}/Best_States/state_dict_{filename}.pth'))

        net.eval()
        with torch.no_grad():
            for inputs, labels in test_dataloader:
                # inputs = torch.swapaxes(inputs, 2, 1)  # -> convert from [10,20] to [20,10]
                inputs = inputs[:, None, :, :]
                inputs = inputs.to(device)
                labels_np = labels.cpu().data.numpy()
                # forward
                outputs, _ = net(inputs)
                outputs_np = softmax_block(outputs)
                outputs_np = outputs_np.cpu().data.numpy()
                outputs_np = np.argmax(outputs_np, axis=1)

                y_pred = np.append(y_pred, outputs_np)
                y_true = np.append(y_true, labels_np)

            cm = metrics.confusion_matrix(y_true=y_true, y_pred=y_pred)
            # Fancy confusion matrix
            plot_confusion_matrix(cm, target_names=exe_labels, title=f'Confusion Matrix for {split_mode} {test_group}',
                                path_to_save=database + f'Cross_{split_mode}/Conf_Matrix/Cross_{split_mode}_N_{filename}.png')

        # %% Write in csv cross_sub results
        # Building columns
        header_net = [f'Tested_{split_mode}', 'Best Val Loss', 'Accuracy', 'Kappa', 'F1_score', 'Best Epoch', 'Norm_Type',
                    'Norm_Mode', 'Rect', f'Valid_{split_mode}']

        # Open the CSV file and write the headers and row of values
        with open(database + f'Cross_{split_mode}/Evals_single_model.csv', 'a', newline='') as myFile:
            writer = csv.writer(myFile)
            if myFile.tell() == 0:
                writer.writerow(header_net)
            # Create the row of values
            row = [test_group, min(val_losses),
                metrics.accuracy_score(y_true=y_true, y_pred=y_pred),
                metrics.cohen_kappa_score(y1=y_true, y2=y_pred, weights='quadratic'),
                metrics.f1_score(y_true=y_true, y_pred=y_pred, average='macro'),
                best_weights['epoch'], NORM_TYPE, NORM_MODE, str(RECT), valid_group]
            writer.writerow(row)
            print(f'Results Saved in -> {database}/Cross_{split_mode}/Evals.csv')

    else:
        for ANGLE in range(1, 6):
            if merged:
                database = data_path + f'/{subj}_offset_relabel/merged_day1_2/'
                name = f'df_merged_wnd_{WND_LEN}_ang_{ANGLE}.csv'
            else:
                database = data_path + f'/{subj}_offset_relabel/day{day}/'
                name = f'Dataframe/dataframe_wnd_{WND_LEN}_angle_{ANGLE}.csv'
            # name merged df: f'df_merged_wnd_{WND_LEN}_ang_{ANGLE}.csv'
            # name normal df: f'Dataframe/dataframe_wnd_{WND_LEN}_angle_{ANGLE}.csv'
            print(database+name)
            df = pd.read_csv(database + name,
                                    dtype={'sub': np.int8, 'label': np.int8, 'rep': np.int8, 'sample_index': np.uint32})
            # Making it lighter
            n_channels = [cx for cx in df.columns if 'ch' in cx]
            df.loc[:, n_channels] = df.loc[:, n_channels].astype(np.float32)

            exe_labels = ['medium_wrap', 'lateral', 'power_sphere', 'power_disk', 'prismatic_pinch', 'index_extension',
                        'wave_out', 'wave_in', 'fist', 'open_hand']
            device = torch.device('cuda')

            #%% Normalization
            print("Normalization process initiated")
            if NORM_WND:
                df = Norm_wnd_each_sub_by_own_param(df, mode= NORM_MODE, norm_type= NORM_TYPE, rectify=RECT )
                #df.to_csv(merge_path + f"wnd_norm_merged_dataframe_{WND_LEN}.csv")
            else:
                df = Norm_each_sub_by_own_param(df, mode= NORM_MODE, norm_type= NORM_TYPE, rectify=RECT )
            #df.to_csv(merge_path + f"norm_merged_dataframe_{WND_LEN}.csv")
            """
            # use this part to create the normalized dataframes
            norm_df = pd.DataFrame()
            chs = [col for col in df.columns if 'ch' in col]
            sample_idxs = np.unique(df['sample_index'])
            print("Starting Window Normalization")
            for idx in sample_idxs:
                data_wnd = df[df['sample_index']==idx]
                data_to_norm = data_wnd.filter(like='ch', axis=1)
                if NORM_MODE == 'sub':
                    normed_data_wnd = NormalizeData(data_to_norm,norm_type=NORM_TYPE)
                    data_wnd.loc[normed_data_wnd.index, chs] = normed_data_wnd
                elif NORM_MODE == 'channel':
                    normed_data_wnd = data_to_norm.copy()
                    for j in data_to_norm.columns:
                        normed_data_wnd[j] = NormalizeData(normed_data_wnd[j], norm_type=NORM_TYPE)
                        data_wnd.loc[normed_data_wnd.index, j] = normed_data_wnd
                norm_df = pd.concat([norm_df, data_wnd], axis=0, ignore_index = True)

            norm_df.to_csv(database + f"/Normalized/norm_{NORM_MODE}_{NORM_TYPE}_wnd_{WND_LEN}_angle_{ANGLE}.csv", index = False)
            print(f"Saved at: {database}/Nomalized/")

            """
            #df = pd.read_csv(database + f"angle_merged/norm_merged_dataframe_200.csv")#norm_{NORM_MODE}_{NORM_TYPE}_wnd_{WND_LEN}_angle_{ANGLE}.csv")

            #%% Split Dataframe

            split_mode = 'rep'
            df_train, df_val, df_test = train_val_test_split_df(df, mode=split_mode, manual_sel=train_val_test_rep)
            # Saving val and test rep used
            valid_group = np.unique(df_val[split_mode])
            test_group = np.unique(df_test[split_mode])[0]
            # %% pandas dataset
            # You must pass to the dataloader a groupby dataframe
            train_set = Pandas_Dataset(df_train.groupby('sample_index'))
            valid_set = Pandas_Dataset(df_val.groupby('sample_index'))
            test_set = Pandas_Dataset(df_test.groupby('sample_index'))
            df_test.set_index('sample_index', inplace = True)
            if save_test_set:
                print("Saving test set...")
                path_to_save = database + f"test_rep{test_rep}/test_sets/"
                if not os.path.exists(path_to_save):
                    os.makedirs(path_to_save)
                df_test.to_csv(path_to_save + f"/test_set_angle_{ANGLE}_merged.csv") if merged else df_test.to_csv(path_to_save + f"test_set_angle_{ANGLE}_day_{day}.csv")
                print(f"Test Set saved")
            # %% Dataloaders
            batch_size = 32
            num_workers = 0
            params = {'batch_size': batch_size,
                    'shuffle': True,
                    # 'sampler': sampler,
                    'num_workers': num_workers,
                    'drop_last': False}

            train_set_generator = data.DataLoader(train_set, **params)
            valid_set_generator = data.DataLoader(valid_set, **params)
            test_set_generator = data.DataLoader(test_set, **params)

            #%% Parametric model
            kernels_gap = [g for g in range(0, 3 * round(WND_LEN / 20), round(WND_LEN / 20))]
            kernel_sizes = np.full((3, 5, 2), [1, 3])
            for j in range(3):
                for i in range(5):
                    kernel_sizes[j][i][0] = (round(WND_LEN / 20) * (i + 1) + kernels_gap[j])

            n_classes = 10

            net = {'N_multik': 32, 'N_Conv_conc': 64, 'N_SepConv': 128,
            'Kernel_multi_dim': kernel_sizes[0],
            'Kernel_Conv_conc': 1,
            'act_func': nn.ReLU(),
            'Pool_Type': nn.MaxPool2d,
            'wnd_len':WND_LEN
            }

            model = MKCNN_grid(net, num_classes=n_classes)
            model = model.to(device)

            #%% Loss Optim and scheduler
            # Define Loss functions
            cross_entropy_loss = nn.CrossEntropyLoss(reduction='mean').to(device)
            # triplet = nn.TripletMarginLoss(reduction='mean', margin=1, p=2)

            # Define Optimizer
            learning_rate = 0.0001
            # changed beta values from (0.5,0.999) to (0.9,0.999)
            optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), weight_decay=1e-4)

            # # Define Scheduler
            precision = 1e-6
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, factor=.2,
                                                                patience=5, verbose=True, eps=precision)

            print(f'Model created with Num params: {sum([p.numel() for p in model.parameters() if p.requires_grad])}')


            # %% Traning model
            # if it doesn't work check if I left the angle in the Pandas_Dataset class
            best_weights, tr_losses, val_losses = train_model_standard(model=model, loss_fun=cross_entropy_loss,
                                                                    optimizer=optimizer, scheduler=scheduler,
                                                                    dataloaders={"train": train_set_generator,
                                                                                    "val": valid_set_generator},
                                                                    num_epochs=50, precision=precision,
                                                                    patience=10, patience_increase=5)

        #%% Saving
            database = save_path
            if merged:
                filename = f'wnd_{WND_LEN}_{NORM_TYPE}_{NORM_MODE}_rect_{RECT}_ang_{ANGLE}_merged'
            else:
                filename = f'wnd_{WND_LEN}_{NORM_TYPE}_{NORM_MODE}_rect_{RECT}_ang_{ANGLE}_day{day}'
            # Save state dict of the model
            if not os.path.exists(database + f'Cross_{split_mode}/Best_States/'):
                os.makedirs(database + f'Cross_{split_mode}/Best_States/')
            torch.save(best_weights['state_dict'],
                    database + f'Cross_{split_mode}/Best_States/state_dict_{filename}.pth')

            # %% PlotLoss
            if not os.path.exists(database + f'Cross_{split_mode}/Plot/'):
                os.makedirs(database + f'Cross_{split_mode}/Plot/')

            PlotLoss(tr_losses, val_loss=val_losses,
                    title=f'Cross-{split_mode}',
                    path_to_save=database + f'Cross_{split_mode}/Plot/',
                    filename=f'Cross_{split_mode}_{filename}.png')

            # %% Conf Matrix
            if not os.path.exists(database + f'Cross_{split_mode}/Conf_Matrix/'):
                os.makedirs(database + f'Cross_{split_mode}/Conf_Matrix/')

            # Evaluation
            softmax_block = nn.Softmax(dim=1)
            y_true = []
            y_pred = []

            test_dataloader = test_set_generator
            net = model
            # Load Weights
            net.load_state_dict(torch.load(database + f'Cross_{split_mode}/Best_States/state_dict_{filename}.pth'))

            net.eval()
            with torch.no_grad():
                for inputs, labels in test_dataloader:
                    # inputs = torch.swapaxes(inputs, 2, 1)  # -> convert from [10,20] to [20,10]
                    inputs = inputs[:, None, :, :]
                    inputs = inputs.to(device)
                    labels_np = labels.cpu().data.numpy()
                    # forward
                    outputs, _ = net(inputs)
                    outputs_np = softmax_block(outputs)
                    outputs_np = outputs_np.cpu().data.numpy()
                    outputs_np = np.argmax(outputs_np, axis=1)

                    y_pred = np.append(y_pred, outputs_np)
                    y_true = np.append(y_true, labels_np)

                cm = metrics.confusion_matrix(y_true=y_true, y_pred=y_pred)
                # Fancy confusion matrix
                plot_confusion_matrix(cm, target_names=exe_labels, title=f'Confusion Matrix for {split_mode} {test_group}',
                                    path_to_save=database + f'Cross_{split_mode}/Conf_Matrix/Cross_{split_mode}_N_{filename}.png')

            # %% Write in csv cross_sub results
            # Building columns
            header_net = [f'Tested_{split_mode}', 'Best Val Loss', 'Accuracy', 'Kappa', 'F1_score', 'Best Epoch', 'Norm_Type',
                        'Norm_Mode', 'Rect', f'Valid_{split_mode}']

            # Open the CSV file and write the headers and row of values
            with open(database + f'Cross_{split_mode}/Evals_multi_model.csv', 'a', newline='') as myFile:
                writer = csv.writer(myFile)
                if myFile.tell() == 0:
                    writer.writerow(header_net)
                # Create the row of values
                row = [test_group, min(val_losses),
                    metrics.accuracy_score(y_true=y_true, y_pred=y_pred),
                    metrics.cohen_kappa_score(y1=y_true, y2=y_pred, weights='quadratic'),
                    metrics.f1_score(y_true=y_true, y_pred=y_pred, average='macro'),
                    best_weights['epoch'], NORM_TYPE, NORM_MODE, str(RECT), valid_group]
                writer.writerow(row)
                print(f'Results Saved in -> {database}/Cross_{split_mode}/Evals.csv')
# Out:
# Test Rep [2]
# /content/drive/MyDrive/Tesi_Magistrale/DATA/Giulio_offset_relabel/day1/Dataframe/dataframe_wnd_200_angle_1.csv
# <ipython-input-30-80749065ac93>:263: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, n_channels] = df.loc[:, n_channels].astype(np.float32)
# Normalization process initiated
# RECTIFICATION OF THE DATAFRAME
# DONE
# Norm SUB: 1
# DONE
# Model created with Num params: 108746
# ######################################################################
#
#
#
#
#  Epoch 0/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 2.31992, accuracy: 0.09375, kappa score: 0.0428, Epoch: -> 0 / 50  Batch Number: -> 1 / 16
# train -> loss: 2.32983, accuracy: 0.09375, kappa score: -0.0182, Epoch: -> 0 / 50  Batch Number: -> 2 / 16
# train -> loss: 2.32881, accuracy: 0.10417, kappa score: 0.0367, Epoch: -> 0 / 50  Batch Number: -> 3 / 16
# train -> loss: 2.32457, accuracy: 0.10938, kappa score: 0.0888, Epoch: -> 0 / 50  Batch Number: -> 4 / 16
# train -> loss: 2.30279, accuracy: 0.13125, kappa score: 0.1235, Epoch: -> 0 / 50  Batch Number: -> 5 / 16
# train -> loss: 2.31263, accuracy: 0.11979, kappa score: 0.0498, Epoch: -> 0 / 50  Batch Number: -> 6 / 16
# train -> loss: 2.29593, accuracy: 0.12946, kappa score: 0.0354, Epoch: -> 0 / 50  Batch Number: -> 7 / 16
# train -> loss: 2.28808, accuracy: 0.13672, kappa score: 0.0277, Epoch: -> 0 / 50  Batch Number: -> 8 / 16
# train -> loss: 2.27852, accuracy: 0.14583, kappa score: 0.0552, Epoch: -> 0 / 50  Batch Number: -> 9 / 16
# train -> loss: 2.27560, accuracy: 0.14062, kappa score: 0.0834, Epoch: -> 0 / 50  Batch Number: -> 10 / 16
# train -> loss: 2.26772, accuracy: 0.14773, kappa score: 0.0915, Epoch: -> 0 / 50  Batch Number: -> 11 / 16
# train -> loss: 2.26373, accuracy: 0.14583, kappa score: 0.0919, Epoch: -> 0 / 50  Batch Number: -> 12 / 16
# train -> loss: 2.25788, accuracy: 0.14663, kappa score: 0.0984, Epoch: -> 0 / 50  Batch Number: -> 13 / 16
# train -> loss: 2.25393, accuracy: 0.15625, kappa score: 0.1011, Epoch: -> 0 / 50  Batch Number: -> 14 / 16
# train -> loss: 2.25129, accuracy: 0.15417, kappa score: 0.1001, Epoch: -> 0 / 50  Batch Number: -> 15 / 16
# train -> loss: 2.25091, accuracy: 0.15230, kappa score: 0.0987, Epoch: -> 0 / 50  Batch Number: -> 16 / 16
# val -> loss: 2.29062, accuracy: 0.12500, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 1 / 31
# val -> loss: 2.30310, accuracy: 0.07812, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 2 / 31
# val -> loss: 2.30100, accuracy: 0.11458, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 3 / 31
# val -> loss: 2.30244, accuracy: 0.10938, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 4 / 31
# val -> loss: 2.30344, accuracy: 0.10000, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 5 / 31
# val -> loss: 2.30450, accuracy: 0.10417, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 6 / 31
# val -> loss: 2.30349, accuracy: 0.10268, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 7 / 31
# val -> loss: 2.30499, accuracy: 0.09766, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 8 / 31
# val -> loss: 2.30293, accuracy: 0.10417, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 9 / 31
# val -> loss: 2.30175, accuracy: 0.10625, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 10 / 31
# val -> loss: 2.30222, accuracy: 0.10511, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 11 / 31
# val -> loss: 2.30173, accuracy: 0.10677, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 12 / 31
# val -> loss: 2.30209, accuracy: 0.10577, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 13 / 31
# val -> loss: 2.30323, accuracy: 0.10268, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 14 / 31
# val -> loss: 2.30346, accuracy: 0.10417, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 15 / 31
# val -> loss: 2.30317, accuracy: 0.10352, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 16 / 31
# val -> loss: 2.30298, accuracy: 0.11029, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 17 / 31
# val -> loss: 2.30259, accuracy: 0.10764, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 18 / 31
# val -> loss: 2.30290, accuracy: 0.10362, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 19 / 31
# val -> loss: 2.30268, accuracy: 0.10469, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 20 / 31
# val -> loss: 2.30250, accuracy: 0.10417, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 21 / 31
# val -> loss: 2.30285, accuracy: 0.10085, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 22 / 31
# val -> loss: 2.30302, accuracy: 0.10054, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 23 / 31
# val -> loss: 2.30263, accuracy: 0.10156, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 24 / 31
# val -> loss: 2.30269, accuracy: 0.09875, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 25 / 31
# val -> loss: 2.30257, accuracy: 0.10216, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 26 / 31
# val -> loss: 2.30233, accuracy: 0.10301, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 27 / 31
# val -> loss: 2.30233, accuracy: 0.10268, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 28 / 31
# val -> loss: 2.30201, accuracy: 0.10776, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 29 / 31
# val -> loss: 2.30209, accuracy: 0.10521, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 30 / 31
# val -> loss: 2.30215, accuracy: 0.10558, kappa score: 0.0000, Epoch: -> 0 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 2.302150318699498
# Epoch 1 of 50 took 3.405s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 1/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 2.13068, accuracy: 0.28125, kappa score: 0.3148, Epoch: -> 1 / 50  Batch Number: -> 1 / 16
# train -> loss: 2.14720, accuracy: 0.26562, kappa score: 0.3383, Epoch: -> 1 / 50  Batch Number: -> 2 / 16
# train -> loss: 2.13908, accuracy: 0.26042, kappa score: 0.2099, Epoch: -> 1 / 50  Batch Number: -> 3 / 16
# train -> loss: 2.13188, accuracy: 0.25000, kappa score: 0.1141, Epoch: -> 1 / 50  Batch Number: -> 4 / 16
# train -> loss: 2.12545, accuracy: 0.25000, kappa score: 0.1161, Epoch: -> 1 / 50  Batch Number: -> 5 / 16
# train -> loss: 2.11965, accuracy: 0.25521, kappa score: 0.1128, Epoch: -> 1 / 50  Batch Number: -> 6 / 16
# train -> loss: 2.10189, accuracy: 0.27232, kappa score: 0.1333, Epoch: -> 1 / 50  Batch Number: -> 7 / 16
# train -> loss: 2.08871, accuracy: 0.27734, kappa score: 0.1795, Epoch: -> 1 / 50  Batch Number: -> 8 / 16
# train -> loss: 2.09122, accuracy: 0.27431, kappa score: 0.1779, Epoch: -> 1 / 50  Batch Number: -> 9 / 16
# train -> loss: 2.08442, accuracy: 0.27187, kappa score: 0.1785, Epoch: -> 1 / 50  Batch Number: -> 10 / 16
# train -> loss: 2.08109, accuracy: 0.26989, kappa score: 0.1507, Epoch: -> 1 / 50  Batch Number: -> 11 / 16
# train -> loss: 2.08008, accuracy: 0.27083, kappa score: 0.2021, Epoch: -> 1 / 50  Batch Number: -> 12 / 16
# train -> loss: 2.07855, accuracy: 0.27644, kappa score: 0.2044, Epoch: -> 1 / 50  Batch Number: -> 13 / 16
# train -> loss: 2.07032, accuracy: 0.28795, kappa score: 0.2317, Epoch: -> 1 / 50  Batch Number: -> 14 / 16
# train -> loss: 2.06772, accuracy: 0.28958, kappa score: 0.2332, Epoch: -> 1 / 50  Batch Number: -> 15 / 16
# train -> loss: 2.06416, accuracy: 0.29459, kappa score: 0.2345, Epoch: -> 1 / 50  Batch Number: -> 16 / 16
# val -> loss: 2.30002, accuracy: 0.15625, kappa score: 0.0000, Epoch: -> 1 / 50  Batch Number: -> 1 / 31
# val -> loss: 2.30222, accuracy: 0.09375, kappa score: 0.0105, Epoch: -> 1 / 50  Batch Number: -> 2 / 31
# val -> loss: 2.29621, accuracy: 0.11458, kappa score: 0.0087, Epoch: -> 1 / 50  Batch Number: -> 3 / 31
# val -> loss: 2.29362, accuracy: 0.11719, kappa score: 0.0053, Epoch: -> 1 / 50  Batch Number: -> 4 / 31
# val -> loss: 2.29159, accuracy: 0.11875, kappa score: 0.0104, Epoch: -> 1 / 50  Batch Number: -> 5 / 31
# val -> loss: 2.29123, accuracy: 0.11979, kappa score: 0.0091, Epoch: -> 1 / 50  Batch Number: -> 6 / 31
# val -> loss: 2.29053, accuracy: 0.12054, kappa score: 0.0073, Epoch: -> 1 / 50  Batch Number: -> 7 / 31
# val -> loss: 2.28755, accuracy: 0.14453, kappa score: 0.0167, Epoch: -> 1 / 50  Batch Number: -> 8 / 31
# val -> loss: 2.28626, accuracy: 0.14583, kappa score: 0.0181, Epoch: -> 1 / 50  Batch Number: -> 9 / 31
# val -> loss: 2.28739, accuracy: 0.14375, kappa score: 0.0202, Epoch: -> 1 / 50  Batch Number: -> 10 / 31
# val -> loss: 2.28802, accuracy: 0.14489, kappa score: 0.0177, Epoch: -> 1 / 50  Batch Number: -> 11 / 31
# val -> loss: 2.28897, accuracy: 0.13542, kappa score: 0.0157, Epoch: -> 1 / 50  Batch Number: -> 12 / 31
# val -> loss: 2.28881, accuracy: 0.12981, kappa score: 0.0117, Epoch: -> 1 / 50  Batch Number: -> 13 / 31
# val -> loss: 2.28966, accuracy: 0.12277, kappa score: 0.0108, Epoch: -> 1 / 50  Batch Number: -> 14 / 31
# val -> loss: 2.28938, accuracy: 0.12708, kappa score: 0.0150, Epoch: -> 1 / 50  Batch Number: -> 15 / 31
# val -> loss: 2.28905, accuracy: 0.12500, kappa score: 0.0115, Epoch: -> 1 / 50  Batch Number: -> 16 / 31
# val -> loss: 2.28999, accuracy: 0.12316, kappa score: 0.0111, Epoch: -> 1 / 50  Batch Number: -> 17 / 31
# val -> loss: 2.29101, accuracy: 0.11806, kappa score: 0.0102, Epoch: -> 1 / 50  Batch Number: -> 18 / 31
# val -> loss: 2.28992, accuracy: 0.12171, kappa score: 0.0098, Epoch: -> 1 / 50  Batch Number: -> 19 / 31
# val -> loss: 2.28993, accuracy: 0.11875, kappa score: 0.0122, Epoch: -> 1 / 50  Batch Number: -> 20 / 31
# val -> loss: 2.29038, accuracy: 0.11905, kappa score: 0.0149, Epoch: -> 1 / 50  Batch Number: -> 21 / 31
# val -> loss: 2.29038, accuracy: 0.12074, kappa score: 0.0127, Epoch: -> 1 / 50  Batch Number: -> 22 / 31
# val -> loss: 2.29010, accuracy: 0.11821, kappa score: 0.0117, Epoch: -> 1 / 50  Batch Number: -> 23 / 31
# val -> loss: 2.28945, accuracy: 0.11589, kappa score: 0.0109, Epoch: -> 1 / 50  Batch Number: -> 24 / 31
# val -> loss: 2.28967, accuracy: 0.11750, kappa score: 0.0130, Epoch: -> 1 / 50  Batch Number: -> 25 / 31
# val -> loss: 2.28962, accuracy: 0.11538, kappa score: 0.0147, Epoch: -> 1 / 50  Batch Number: -> 26 / 31
# val -> loss: 2.28963, accuracy: 0.11458, kappa score: 0.0141, Epoch: -> 1 / 50  Batch Number: -> 27 / 31
# val -> loss: 2.28968, accuracy: 0.11272, kappa score: 0.0138, Epoch: -> 1 / 50  Batch Number: -> 28 / 31
# val -> loss: 2.28933, accuracy: 0.11207, kappa score: 0.0121, Epoch: -> 1 / 50  Batch Number: -> 29 / 31
# val -> loss: 2.28893, accuracy: 0.11563, kappa score: 0.0108, Epoch: -> 1 / 50  Batch Number: -> 30 / 31
# val -> loss: 2.28846, accuracy: 0.11675, kappa score: 0.0105, Epoch: -> 1 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 2.2884626696186676
# Epoch 2 of 50 took 3.395s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 2/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 2.03364, accuracy: 0.37500, kappa score: 0.4991, Epoch: -> 2 / 50  Batch Number: -> 1 / 16
# train -> loss: 2.04984, accuracy: 0.32812, kappa score: 0.4572, Epoch: -> 2 / 50  Batch Number: -> 2 / 16
# train -> loss: 2.03984, accuracy: 0.32292, kappa score: 0.4967, Epoch: -> 2 / 50  Batch Number: -> 3 / 16
# train -> loss: 2.00227, accuracy: 0.35156, kappa score: 0.5108, Epoch: -> 2 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.99763, accuracy: 0.33750, kappa score: 0.4609, Epoch: -> 2 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.97239, accuracy: 0.36458, kappa score: 0.4385, Epoch: -> 2 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.97372, accuracy: 0.36161, kappa score: 0.4185, Epoch: -> 2 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.96802, accuracy: 0.37500, kappa score: 0.3732, Epoch: -> 2 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.96105, accuracy: 0.38194, kappa score: 0.3691, Epoch: -> 2 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.95474, accuracy: 0.38438, kappa score: 0.3804, Epoch: -> 2 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.94392, accuracy: 0.38636, kappa score: 0.3909, Epoch: -> 2 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.94551, accuracy: 0.38281, kappa score: 0.3891, Epoch: -> 2 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.93752, accuracy: 0.38462, kappa score: 0.3874, Epoch: -> 2 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.92807, accuracy: 0.38616, kappa score: 0.3888, Epoch: -> 2 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.92697, accuracy: 0.38750, kappa score: 0.3904, Epoch: -> 2 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.93036, accuracy: 0.38076, kappa score: 0.3784, Epoch: -> 2 / 50  Batch Number: -> 16 / 16
# val -> loss: 2.10785, accuracy: 0.50000, kappa score: 0.3604, Epoch: -> 2 / 50  Batch Number: -> 1 / 31
# val -> loss: 2.14030, accuracy: 0.45312, kappa score: 0.2509, Epoch: -> 2 / 50  Batch Number: -> 2 / 31
# val -> loss: 2.12371, accuracy: 0.43750, kappa score: 0.2605, Epoch: -> 2 / 50  Batch Number: -> 3 / 31
# val -> loss: 2.13450, accuracy: 0.42969, kappa score: 0.2263, Epoch: -> 2 / 50  Batch Number: -> 4 / 31
# val -> loss: 2.14708, accuracy: 0.43750, kappa score: 0.2556, Epoch: -> 2 / 50  Batch Number: -> 5 / 31
# val -> loss: 2.13509, accuracy: 0.45833, kappa score: 0.3336, Epoch: -> 2 / 50  Batch Number: -> 6 / 31
# val -> loss: 2.13924, accuracy: 0.45982, kappa score: 0.3626, Epoch: -> 2 / 50  Batch Number: -> 7 / 31
# val -> loss: 2.13684, accuracy: 0.46094, kappa score: 0.3759, Epoch: -> 2 / 50  Batch Number: -> 8 / 31
# val -> loss: 2.14216, accuracy: 0.47222, kappa score: 0.3863, Epoch: -> 2 / 50  Batch Number: -> 9 / 31
# val -> loss: 2.13655, accuracy: 0.47813, kappa score: 0.3896, Epoch: -> 2 / 50  Batch Number: -> 10 / 31
# val -> loss: 2.13568, accuracy: 0.48011, kappa score: 0.3893, Epoch: -> 2 / 50  Batch Number: -> 11 / 31
# val -> loss: 2.13199, accuracy: 0.48958, kappa score: 0.3954, Epoch: -> 2 / 50  Batch Number: -> 12 / 31
# val -> loss: 2.13244, accuracy: 0.48558, kappa score: 0.4014, Epoch: -> 2 / 50  Batch Number: -> 13 / 31
# val -> loss: 2.13108, accuracy: 0.48214, kappa score: 0.4156, Epoch: -> 2 / 50  Batch Number: -> 14 / 31
# val -> loss: 2.13230, accuracy: 0.47292, kappa score: 0.4040, Epoch: -> 2 / 50  Batch Number: -> 15 / 31
# val -> loss: 2.13024, accuracy: 0.46289, kappa score: 0.3866, Epoch: -> 2 / 50  Batch Number: -> 16 / 31
# val -> loss: 2.12435, accuracy: 0.46875, kappa score: 0.3852, Epoch: -> 2 / 50  Batch Number: -> 17 / 31
# val -> loss: 2.12200, accuracy: 0.47222, kappa score: 0.3995, Epoch: -> 2 / 50  Batch Number: -> 18 / 31
# val -> loss: 2.12172, accuracy: 0.46546, kappa score: 0.4021, Epoch: -> 2 / 50  Batch Number: -> 19 / 31
# val -> loss: 2.12140, accuracy: 0.46094, kappa score: 0.4012, Epoch: -> 2 / 50  Batch Number: -> 20 / 31
# val -> loss: 2.12154, accuracy: 0.45685, kappa score: 0.3853, Epoch: -> 2 / 50  Batch Number: -> 21 / 31
# val -> loss: 2.12060, accuracy: 0.45881, kappa score: 0.3774, Epoch: -> 2 / 50  Batch Number: -> 22 / 31
# val -> loss: 2.12258, accuracy: 0.45652, kappa score: 0.3665, Epoch: -> 2 / 50  Batch Number: -> 23 / 31
# val -> loss: 2.12326, accuracy: 0.45703, kappa score: 0.3648, Epoch: -> 2 / 50  Batch Number: -> 24 / 31
# val -> loss: 2.12381, accuracy: 0.45500, kappa score: 0.3507, Epoch: -> 2 / 50  Batch Number: -> 25 / 31
# val -> loss: 2.12435, accuracy: 0.44952, kappa score: 0.3380, Epoch: -> 2 / 50  Batch Number: -> 26 / 31
# val -> loss: 2.12257, accuracy: 0.44560, kappa score: 0.3393, Epoch: -> 2 / 50  Batch Number: -> 27 / 31
# val -> loss: 2.12094, accuracy: 0.44643, kappa score: 0.3403, Epoch: -> 2 / 50  Batch Number: -> 28 / 31
# val -> loss: 2.11928, accuracy: 0.44612, kappa score: 0.3276, Epoch: -> 2 / 50  Batch Number: -> 29 / 31
# val -> loss: 2.11907, accuracy: 0.44167, kappa score: 0.3263, Epoch: -> 2 / 50  Batch Number: -> 30 / 31
# val -> loss: 2.11909, accuracy: 0.44162, kappa score: 0.3283, Epoch: -> 2 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 2.11908963418776
# Epoch 3 of 50 took 3.981s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 3/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 1.93302, accuracy: 0.28125, kappa score: 0.4699, Epoch: -> 3 / 50  Batch Number: -> 1 / 16
# train -> loss: 1.97641, accuracy: 0.20312, kappa score: 0.2277, Epoch: -> 3 / 50  Batch Number: -> 2 / 16
# train -> loss: 1.93933, accuracy: 0.28125, kappa score: 0.3547, Epoch: -> 3 / 50  Batch Number: -> 3 / 16
# train -> loss: 1.85463, accuracy: 0.35938, kappa score: 0.4218, Epoch: -> 3 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.85528, accuracy: 0.36875, kappa score: 0.4728, Epoch: -> 3 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.84905, accuracy: 0.36458, kappa score: 0.4410, Epoch: -> 3 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.85379, accuracy: 0.37946, kappa score: 0.4435, Epoch: -> 3 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.84267, accuracy: 0.40234, kappa score: 0.4793, Epoch: -> 3 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.83458, accuracy: 0.39583, kappa score: 0.4699, Epoch: -> 3 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.82050, accuracy: 0.39687, kappa score: 0.4738, Epoch: -> 3 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.81122, accuracy: 0.41477, kappa score: 0.4856, Epoch: -> 3 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.82004, accuracy: 0.41927, kappa score: 0.4731, Epoch: -> 3 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.82069, accuracy: 0.41827, kappa score: 0.4641, Epoch: -> 3 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.81574, accuracy: 0.42188, kappa score: 0.4688, Epoch: -> 3 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.81065, accuracy: 0.42500, kappa score: 0.4783, Epoch: -> 3 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.81078, accuracy: 0.42685, kappa score: 0.4727, Epoch: -> 3 / 50  Batch Number: -> 16 / 16
# val -> loss: 1.69809, accuracy: 0.68750, kappa score: 0.7006, Epoch: -> 3 / 50  Batch Number: -> 1 / 31
# val -> loss: 1.80875, accuracy: 0.62500, kappa score: 0.5361, Epoch: -> 3 / 50  Batch Number: -> 2 / 31
# val -> loss: 1.80903, accuracy: 0.66667, kappa score: 0.5762, Epoch: -> 3 / 50  Batch Number: -> 3 / 31
# val -> loss: 1.83059, accuracy: 0.62500, kappa score: 0.5516, Epoch: -> 3 / 50  Batch Number: -> 4 / 31
# val -> loss: 1.83872, accuracy: 0.61250, kappa score: 0.5077, Epoch: -> 3 / 50  Batch Number: -> 5 / 31
# val -> loss: 1.84986, accuracy: 0.58854, kappa score: 0.5130, Epoch: -> 3 / 50  Batch Number: -> 6 / 31
# val -> loss: 1.86525, accuracy: 0.59375, kappa score: 0.5292, Epoch: -> 3 / 50  Batch Number: -> 7 / 31
# val -> loss: 1.88380, accuracy: 0.57812, kappa score: 0.5006, Epoch: -> 3 / 50  Batch Number: -> 8 / 31
# val -> loss: 1.86631, accuracy: 0.57639, kappa score: 0.5152, Epoch: -> 3 / 50  Batch Number: -> 9 / 31
# val -> loss: 1.86032, accuracy: 0.56875, kappa score: 0.5104, Epoch: -> 3 / 50  Batch Number: -> 10 / 31
# val -> loss: 1.85673, accuracy: 0.56250, kappa score: 0.5032, Epoch: -> 3 / 50  Batch Number: -> 11 / 31
# val -> loss: 1.85173, accuracy: 0.57292, kappa score: 0.5032, Epoch: -> 3 / 50  Batch Number: -> 12 / 31
# val -> loss: 1.84838, accuracy: 0.56731, kappa score: 0.4752, Epoch: -> 3 / 50  Batch Number: -> 13 / 31
# val -> loss: 1.83395, accuracy: 0.56920, kappa score: 0.4699, Epoch: -> 3 / 50  Batch Number: -> 14 / 31
# val -> loss: 1.83923, accuracy: 0.57292, kappa score: 0.4527, Epoch: -> 3 / 50  Batch Number: -> 15 / 31
# val -> loss: 1.84259, accuracy: 0.56445, kappa score: 0.4346, Epoch: -> 3 / 50  Batch Number: -> 16 / 31
# val -> loss: 1.84545, accuracy: 0.55882, kappa score: 0.4397, Epoch: -> 3 / 50  Batch Number: -> 17 / 31
# val -> loss: 1.85304, accuracy: 0.56424, kappa score: 0.4528, Epoch: -> 3 / 50  Batch Number: -> 18 / 31
# val -> loss: 1.85243, accuracy: 0.56250, kappa score: 0.4648, Epoch: -> 3 / 50  Batch Number: -> 19 / 31
# val -> loss: 1.86230, accuracy: 0.56250, kappa score: 0.4598, Epoch: -> 3 / 50  Batch Number: -> 20 / 31
# val -> loss: 1.86713, accuracy: 0.55804, kappa score: 0.4480, Epoch: -> 3 / 50  Batch Number: -> 21 / 31
# val -> loss: 1.86906, accuracy: 0.55682, kappa score: 0.4478, Epoch: -> 3 / 50  Batch Number: -> 22 / 31
# val -> loss: 1.87522, accuracy: 0.54891, kappa score: 0.4474, Epoch: -> 3 / 50  Batch Number: -> 23 / 31
# val -> loss: 1.87994, accuracy: 0.54818, kappa score: 0.4589, Epoch: -> 3 / 50  Batch Number: -> 24 / 31
# val -> loss: 1.87281, accuracy: 0.55125, kappa score: 0.4643, Epoch: -> 3 / 50  Batch Number: -> 25 / 31
# val -> loss: 1.87018, accuracy: 0.55048, kappa score: 0.4601, Epoch: -> 3 / 50  Batch Number: -> 26 / 31
# val -> loss: 1.86648, accuracy: 0.55671, kappa score: 0.4706, Epoch: -> 3 / 50  Batch Number: -> 27 / 31
# val -> loss: 1.86963, accuracy: 0.55246, kappa score: 0.4655, Epoch: -> 3 / 50  Batch Number: -> 28 / 31
# val -> loss: 1.87062, accuracy: 0.55065, kappa score: 0.4603, Epoch: -> 3 / 50  Batch Number: -> 29 / 31
# val -> loss: 1.87484, accuracy: 0.54896, kappa score: 0.4499, Epoch: -> 3 / 50  Batch Number: -> 30 / 31
# val -> loss: 1.87290, accuracy: 0.55228, kappa score: 0.4563, Epoch: -> 3 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 1.8729001706646335
# Epoch 4 of 50 took 3.857s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 4/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 1.71997, accuracy: 0.53125, kappa score: 0.7280, Epoch: -> 4 / 50  Batch Number: -> 1 / 16
# train -> loss: 1.69467, accuracy: 0.51562, kappa score: 0.6874, Epoch: -> 4 / 50  Batch Number: -> 2 / 16
# train -> loss: 1.70346, accuracy: 0.50000, kappa score: 0.6317, Epoch: -> 4 / 50  Batch Number: -> 3 / 16
# train -> loss: 1.70749, accuracy: 0.50000, kappa score: 0.6164, Epoch: -> 4 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.71950, accuracy: 0.47500, kappa score: 0.6078, Epoch: -> 4 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.72839, accuracy: 0.47396, kappa score: 0.6333, Epoch: -> 4 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.71698, accuracy: 0.48214, kappa score: 0.6257, Epoch: -> 4 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.70951, accuracy: 0.49219, kappa score: 0.6052, Epoch: -> 4 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.71566, accuracy: 0.50347, kappa score: 0.5999, Epoch: -> 4 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.71385, accuracy: 0.50625, kappa score: 0.6214, Epoch: -> 4 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.70791, accuracy: 0.50568, kappa score: 0.6210, Epoch: -> 4 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.69300, accuracy: 0.51562, kappa score: 0.6214, Epoch: -> 4 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.69259, accuracy: 0.51683, kappa score: 0.6136, Epoch: -> 4 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.68612, accuracy: 0.51562, kappa score: 0.6078, Epoch: -> 4 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.69062, accuracy: 0.50833, kappa score: 0.6065, Epoch: -> 4 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.69508, accuracy: 0.50701, kappa score: 0.6074, Epoch: -> 4 / 50  Batch Number: -> 16 / 16
# val -> loss: 1.58220, accuracy: 0.65625, kappa score: 0.5749, Epoch: -> 4 / 50  Batch Number: -> 1 / 31
# val -> loss: 1.61757, accuracy: 0.65625, kappa score: 0.5039, Epoch: -> 4 / 50  Batch Number: -> 2 / 31
# val -> loss: 1.57686, accuracy: 0.68750, kappa score: 0.4809, Epoch: -> 4 / 50  Batch Number: -> 3 / 31
# val -> loss: 1.63452, accuracy: 0.68750, kappa score: 0.5740, Epoch: -> 4 / 50  Batch Number: -> 4 / 31
# val -> loss: 1.64781, accuracy: 0.68125, kappa score: 0.6243, Epoch: -> 4 / 50  Batch Number: -> 5 / 31
# val -> loss: 1.68332, accuracy: 0.64583, kappa score: 0.6048, Epoch: -> 4 / 50  Batch Number: -> 6 / 31
# val -> loss: 1.68397, accuracy: 0.63839, kappa score: 0.5703, Epoch: -> 4 / 50  Batch Number: -> 7 / 31
# val -> loss: 1.68642, accuracy: 0.63281, kappa score: 0.5322, Epoch: -> 4 / 50  Batch Number: -> 8 / 31
# val -> loss: 1.68190, accuracy: 0.63542, kappa score: 0.5142, Epoch: -> 4 / 50  Batch Number: -> 9 / 31
# val -> loss: 1.69250, accuracy: 0.63125, kappa score: 0.5309, Epoch: -> 4 / 50  Batch Number: -> 10 / 31
# val -> loss: 1.69039, accuracy: 0.62216, kappa score: 0.5498, Epoch: -> 4 / 50  Batch Number: -> 11 / 31
# val -> loss: 1.66927, accuracy: 0.63021, kappa score: 0.5519, Epoch: -> 4 / 50  Batch Number: -> 12 / 31
# val -> loss: 1.67889, accuracy: 0.62981, kappa score: 0.5492, Epoch: -> 4 / 50  Batch Number: -> 13 / 31
# val -> loss: 1.67917, accuracy: 0.62946, kappa score: 0.5546, Epoch: -> 4 / 50  Batch Number: -> 14 / 31
# val -> loss: 1.68764, accuracy: 0.62917, kappa score: 0.5545, Epoch: -> 4 / 50  Batch Number: -> 15 / 31
# val -> loss: 1.68419, accuracy: 0.63281, kappa score: 0.5578, Epoch: -> 4 / 50  Batch Number: -> 16 / 31
# val -> loss: 1.69456, accuracy: 0.62868, kappa score: 0.5427, Epoch: -> 4 / 50  Batch Number: -> 17 / 31
# val -> loss: 1.69853, accuracy: 0.62153, kappa score: 0.5378, Epoch: -> 4 / 50  Batch Number: -> 18 / 31
# val -> loss: 1.71304, accuracy: 0.61020, kappa score: 0.5262, Epoch: -> 4 / 50  Batch Number: -> 19 / 31
# val -> loss: 1.71660, accuracy: 0.61406, kappa score: 0.5383, Epoch: -> 4 / 50  Batch Number: -> 20 / 31
# val -> loss: 1.71081, accuracy: 0.61012, kappa score: 0.5348, Epoch: -> 4 / 50  Batch Number: -> 21 / 31
# val -> loss: 1.71547, accuracy: 0.60511, kappa score: 0.5193, Epoch: -> 4 / 50  Batch Number: -> 22 / 31
# val -> loss: 1.72206, accuracy: 0.60190, kappa score: 0.5204, Epoch: -> 4 / 50  Batch Number: -> 23 / 31
# val -> loss: 1.72834, accuracy: 0.59766, kappa score: 0.5204, Epoch: -> 4 / 50  Batch Number: -> 24 / 31
# val -> loss: 1.72474, accuracy: 0.60000, kappa score: 0.5145, Epoch: -> 4 / 50  Batch Number: -> 25 / 31
# val -> loss: 1.72257, accuracy: 0.59976, kappa score: 0.5111, Epoch: -> 4 / 50  Batch Number: -> 26 / 31
# val -> loss: 1.72457, accuracy: 0.59606, kappa score: 0.5097, Epoch: -> 4 / 50  Batch Number: -> 27 / 31
# val -> loss: 1.72036, accuracy: 0.60045, kappa score: 0.5163, Epoch: -> 4 / 50  Batch Number: -> 28 / 31
# val -> loss: 1.72768, accuracy: 0.60237, kappa score: 0.5154, Epoch: -> 4 / 50  Batch Number: -> 29 / 31
# val -> loss: 1.73046, accuracy: 0.60417, kappa score: 0.5188, Epoch: -> 4 / 50  Batch Number: -> 30 / 31
# val -> loss: 1.73594, accuracy: 0.60406, kappa score: 0.5164, Epoch: -> 4 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 1.7359360379557456
# Epoch 5 of 50 took 3.360s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 5/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 1.56774, accuracy: 0.53125, kappa score: 0.6577, Epoch: -> 5 / 50  Batch Number: -> 1 / 16
# train -> loss: 1.61041, accuracy: 0.54688, kappa score: 0.5596, Epoch: -> 5 / 50  Batch Number: -> 2 / 16
# train -> loss: 1.64108, accuracy: 0.50000, kappa score: 0.5576, Epoch: -> 5 / 50  Batch Number: -> 3 / 16
# train -> loss: 1.60137, accuracy: 0.53906, kappa score: 0.6109, Epoch: -> 5 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.62637, accuracy: 0.52500, kappa score: 0.5946, Epoch: -> 5 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.62137, accuracy: 0.52083, kappa score: 0.6127, Epoch: -> 5 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.62009, accuracy: 0.52232, kappa score: 0.6070, Epoch: -> 5 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.60856, accuracy: 0.53516, kappa score: 0.6285, Epoch: -> 5 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.60597, accuracy: 0.54167, kappa score: 0.6403, Epoch: -> 5 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.59278, accuracy: 0.55625, kappa score: 0.6330, Epoch: -> 5 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.58670, accuracy: 0.55114, kappa score: 0.6401, Epoch: -> 5 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.57246, accuracy: 0.56250, kappa score: 0.6477, Epoch: -> 5 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.56810, accuracy: 0.56010, kappa score: 0.6501, Epoch: -> 5 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.57384, accuracy: 0.55804, kappa score: 0.6445, Epoch: -> 5 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.56427, accuracy: 0.57292, kappa score: 0.6567, Epoch: -> 5 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.57031, accuracy: 0.56914, kappa score: 0.6564, Epoch: -> 5 / 50  Batch Number: -> 16 / 16
# val -> loss: 1.68780, accuracy: 0.50000, kappa score: 0.2223, Epoch: -> 5 / 50  Batch Number: -> 1 / 31
# val -> loss: 1.71131, accuracy: 0.53125, kappa score: 0.5183, Epoch: -> 5 / 50  Batch Number: -> 2 / 31
# val -> loss: 1.72708, accuracy: 0.50000, kappa score: 0.4476, Epoch: -> 5 / 50  Batch Number: -> 3 / 31
# val -> loss: 1.71941, accuracy: 0.50000, kappa score: 0.3847, Epoch: -> 5 / 50  Batch Number: -> 4 / 31
# val -> loss: 1.66106, accuracy: 0.53125, kappa score: 0.4203, Epoch: -> 5 / 50  Batch Number: -> 5 / 31
# val -> loss: 1.65888, accuracy: 0.53646, kappa score: 0.4248, Epoch: -> 5 / 50  Batch Number: -> 6 / 31
# val -> loss: 1.66583, accuracy: 0.53571, kappa score: 0.4011, Epoch: -> 5 / 50  Batch Number: -> 7 / 31
# val -> loss: 1.66496, accuracy: 0.54297, kappa score: 0.4146, Epoch: -> 5 / 50  Batch Number: -> 8 / 31
# val -> loss: 1.67495, accuracy: 0.54167, kappa score: 0.4365, Epoch: -> 5 / 50  Batch Number: -> 9 / 31
# val -> loss: 1.67001, accuracy: 0.55625, kappa score: 0.4463, Epoch: -> 5 / 50  Batch Number: -> 10 / 31
# val -> loss: 1.68033, accuracy: 0.54261, kappa score: 0.4228, Epoch: -> 5 / 50  Batch Number: -> 11 / 31
# val -> loss: 1.67609, accuracy: 0.54427, kappa score: 0.4164, Epoch: -> 5 / 50  Batch Number: -> 12 / 31
# val -> loss: 1.66091, accuracy: 0.55048, kappa score: 0.4305, Epoch: -> 5 / 50  Batch Number: -> 13 / 31
# val -> loss: 1.66504, accuracy: 0.54464, kappa score: 0.4408, Epoch: -> 5 / 50  Batch Number: -> 14 / 31
# val -> loss: 1.65894, accuracy: 0.55208, kappa score: 0.4346, Epoch: -> 5 / 50  Batch Number: -> 15 / 31
# val -> loss: 1.66245, accuracy: 0.55469, kappa score: 0.4392, Epoch: -> 5 / 50  Batch Number: -> 16 / 31
# val -> loss: 1.67056, accuracy: 0.55147, kappa score: 0.4204, Epoch: -> 5 / 50  Batch Number: -> 17 / 31
# val -> loss: 1.67588, accuracy: 0.54861, kappa score: 0.4270, Epoch: -> 5 / 50  Batch Number: -> 18 / 31
# val -> loss: 1.67392, accuracy: 0.55428, kappa score: 0.4265, Epoch: -> 5 / 50  Batch Number: -> 19 / 31
# val -> loss: 1.67464, accuracy: 0.55781, kappa score: 0.4344, Epoch: -> 5 / 50  Batch Number: -> 20 / 31
# val -> loss: 1.66646, accuracy: 0.56399, kappa score: 0.4421, Epoch: -> 5 / 50  Batch Number: -> 21 / 31
# val -> loss: 1.66032, accuracy: 0.56676, kappa score: 0.4470, Epoch: -> 5 / 50  Batch Number: -> 22 / 31
# val -> loss: 1.65247, accuracy: 0.56793, kappa score: 0.4505, Epoch: -> 5 / 50  Batch Number: -> 23 / 31
# val -> loss: 1.64476, accuracy: 0.57031, kappa score: 0.4482, Epoch: -> 5 / 50  Batch Number: -> 24 / 31
# val -> loss: 1.64758, accuracy: 0.57375, kappa score: 0.4534, Epoch: -> 5 / 50  Batch Number: -> 25 / 31
# val -> loss: 1.63995, accuracy: 0.57933, kappa score: 0.4601, Epoch: -> 5 / 50  Batch Number: -> 26 / 31
# val -> loss: 1.64036, accuracy: 0.58333, kappa score: 0.4628, Epoch: -> 5 / 50  Batch Number: -> 27 / 31
# val -> loss: 1.64125, accuracy: 0.58594, kappa score: 0.4710, Epoch: -> 5 / 50  Batch Number: -> 28 / 31
# val -> loss: 1.64595, accuracy: 0.57543, kappa score: 0.4615, Epoch: -> 5 / 50  Batch Number: -> 29 / 31
# val -> loss: 1.64785, accuracy: 0.56979, kappa score: 0.4589, Epoch: -> 5 / 50  Batch Number: -> 30 / 31
# val -> loss: 1.65095, accuracy: 0.56853, kappa score: 0.4502, Epoch: -> 5 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 1.650947501582484
# Epoch 6 of 50 took 3.399s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 6/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 1.68368, accuracy: 0.50000, kappa score: 0.6626, Epoch: -> 6 / 50  Batch Number: -> 1 / 16
# train -> loss: 1.62707, accuracy: 0.53125, kappa score: 0.5427, Epoch: -> 6 / 50  Batch Number: -> 2 / 16
# train -> loss: 1.59967, accuracy: 0.52083, kappa score: 0.5186, Epoch: -> 6 / 50  Batch Number: -> 3 / 16
# train -> loss: 1.56841, accuracy: 0.56250, kappa score: 0.5914, Epoch: -> 6 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.56832, accuracy: 0.55000, kappa score: 0.6033, Epoch: -> 6 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.56169, accuracy: 0.58333, kappa score: 0.6392, Epoch: -> 6 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.54521, accuracy: 0.58036, kappa score: 0.6433, Epoch: -> 6 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.55179, accuracy: 0.56641, kappa score: 0.6260, Epoch: -> 6 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.54617, accuracy: 0.56597, kappa score: 0.6468, Epoch: -> 6 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.52474, accuracy: 0.56563, kappa score: 0.6485, Epoch: -> 6 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.53111, accuracy: 0.55966, kappa score: 0.6343, Epoch: -> 6 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.52224, accuracy: 0.56250, kappa score: 0.6534, Epoch: -> 6 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.51753, accuracy: 0.55529, kappa score: 0.6483, Epoch: -> 6 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.51041, accuracy: 0.55580, kappa score: 0.6582, Epoch: -> 6 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.50258, accuracy: 0.56458, kappa score: 0.6691, Epoch: -> 6 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.49495, accuracy: 0.56513, kappa score: 0.6778, Epoch: -> 6 / 50  Batch Number: -> 16 / 16
# val -> loss: 1.53830, accuracy: 0.43750, kappa score: 0.1784, Epoch: -> 6 / 50  Batch Number: -> 1 / 31
# val -> loss: 1.46580, accuracy: 0.50000, kappa score: 0.3861, Epoch: -> 6 / 50  Batch Number: -> 2 / 31
# val -> loss: 1.56724, accuracy: 0.44792, kappa score: 0.1930, Epoch: -> 6 / 50  Batch Number: -> 3 / 31
# val -> loss: 1.53491, accuracy: 0.48438, kappa score: 0.3206, Epoch: -> 6 / 50  Batch Number: -> 4 / 31
# val -> loss: 1.51950, accuracy: 0.49375, kappa score: 0.2865, Epoch: -> 6 / 50  Batch Number: -> 5 / 31
# val -> loss: 1.51401, accuracy: 0.51042, kappa score: 0.3572, Epoch: -> 6 / 50  Batch Number: -> 6 / 31
# val -> loss: 1.53072, accuracy: 0.53125, kappa score: 0.3500, Epoch: -> 6 / 50  Batch Number: -> 7 / 31
# val -> loss: 1.54942, accuracy: 0.51562, kappa score: 0.3449, Epoch: -> 6 / 50  Batch Number: -> 8 / 31
# val -> loss: 1.55786, accuracy: 0.52083, kappa score: 0.3403, Epoch: -> 6 / 50  Batch Number: -> 9 / 31
# val -> loss: 1.57042, accuracy: 0.51875, kappa score: 0.3427, Epoch: -> 6 / 50  Batch Number: -> 10 / 31
# val -> loss: 1.57874, accuracy: 0.50284, kappa score: 0.3345, Epoch: -> 6 / 50  Batch Number: -> 11 / 31
# val -> loss: 1.57829, accuracy: 0.51823, kappa score: 0.3768, Epoch: -> 6 / 50  Batch Number: -> 12 / 31
# val -> loss: 1.58288, accuracy: 0.51923, kappa score: 0.3810, Epoch: -> 6 / 50  Batch Number: -> 13 / 31
# val -> loss: 1.59097, accuracy: 0.52455, kappa score: 0.3952, Epoch: -> 6 / 50  Batch Number: -> 14 / 31
# val -> loss: 1.58680, accuracy: 0.52917, kappa score: 0.3880, Epoch: -> 6 / 50  Batch Number: -> 15 / 31
# val -> loss: 1.58025, accuracy: 0.54102, kappa score: 0.4030, Epoch: -> 6 / 50  Batch Number: -> 16 / 31
# val -> loss: 1.57497, accuracy: 0.53860, kappa score: 0.4118, Epoch: -> 6 / 50  Batch Number: -> 17 / 31
# val -> loss: 1.58097, accuracy: 0.53819, kappa score: 0.4132, Epoch: -> 6 / 50  Batch Number: -> 18 / 31
# val -> loss: 1.58605, accuracy: 0.53947, kappa score: 0.4203, Epoch: -> 6 / 50  Batch Number: -> 19 / 31
# val -> loss: 1.58960, accuracy: 0.54531, kappa score: 0.4224, Epoch: -> 6 / 50  Batch Number: -> 20 / 31
# val -> loss: 1.58608, accuracy: 0.55357, kappa score: 0.4346, Epoch: -> 6 / 50  Batch Number: -> 21 / 31
# val -> loss: 1.58315, accuracy: 0.55398, kappa score: 0.4387, Epoch: -> 6 / 50  Batch Number: -> 22 / 31
# val -> loss: 1.58587, accuracy: 0.55027, kappa score: 0.4300, Epoch: -> 6 / 50  Batch Number: -> 23 / 31
# val -> loss: 1.58201, accuracy: 0.55208, kappa score: 0.4337, Epoch: -> 6 / 50  Batch Number: -> 24 / 31
# val -> loss: 1.58244, accuracy: 0.55125, kappa score: 0.4291, Epoch: -> 6 / 50  Batch Number: -> 25 / 31
# val -> loss: 1.57936, accuracy: 0.55168, kappa score: 0.4218, Epoch: -> 6 / 50  Batch Number: -> 26 / 31
# val -> loss: 1.58607, accuracy: 0.55093, kappa score: 0.4121, Epoch: -> 6 / 50  Batch Number: -> 27 / 31
# val -> loss: 1.58112, accuracy: 0.55580, kappa score: 0.4185, Epoch: -> 6 / 50  Batch Number: -> 28 / 31
# val -> loss: 1.58199, accuracy: 0.55280, kappa score: 0.4133, Epoch: -> 6 / 50  Batch Number: -> 29 / 31
# val -> loss: 1.57900, accuracy: 0.55417, kappa score: 0.4178, Epoch: -> 6 / 50  Batch Number: -> 30 / 31
# val -> loss: 1.58259, accuracy: 0.55330, kappa score: 0.4158, Epoch: -> 6 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 1.5825920758708831
# Epoch 7 of 50 took 4.240s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 7/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 1.35157, accuracy: 0.75000, kappa score: 0.9184, Epoch: -> 7 / 50  Batch Number: -> 1 / 16
# train -> loss: 1.50375, accuracy: 0.65625, kappa score: 0.8021, Epoch: -> 7 / 50  Batch Number: -> 2 / 16
# train -> loss: 1.42633, accuracy: 0.64583, kappa score: 0.7507, Epoch: -> 7 / 50  Batch Number: -> 3 / 16
# train -> loss: 1.42810, accuracy: 0.63281, kappa score: 0.7624, Epoch: -> 7 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.41908, accuracy: 0.63125, kappa score: 0.7518, Epoch: -> 7 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.39860, accuracy: 0.65104, kappa score: 0.7685, Epoch: -> 7 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.39640, accuracy: 0.64286, kappa score: 0.7329, Epoch: -> 7 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.39698, accuracy: 0.62109, kappa score: 0.7109, Epoch: -> 7 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.40298, accuracy: 0.61806, kappa score: 0.7245, Epoch: -> 7 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.38294, accuracy: 0.62187, kappa score: 0.7188, Epoch: -> 7 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.38226, accuracy: 0.62500, kappa score: 0.7153, Epoch: -> 7 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.38131, accuracy: 0.62500, kappa score: 0.7006, Epoch: -> 7 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.39203, accuracy: 0.62500, kappa score: 0.6970, Epoch: -> 7 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.38914, accuracy: 0.62500, kappa score: 0.6877, Epoch: -> 7 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.40052, accuracy: 0.61667, kappa score: 0.6883, Epoch: -> 7 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.38556, accuracy: 0.62525, kappa score: 0.7002, Epoch: -> 7 / 50  Batch Number: -> 16 / 16
# val -> loss: 1.42580, accuracy: 0.62500, kappa score: 0.0912, Epoch: -> 7 / 50  Batch Number: -> 1 / 31
# val -> loss: 1.48787, accuracy: 0.56250, kappa score: 0.2235, Epoch: -> 7 / 50  Batch Number: -> 2 / 31
# val -> loss: 1.50965, accuracy: 0.57292, kappa score: 0.2344, Epoch: -> 7 / 50  Batch Number: -> 3 / 31
# val -> loss: 1.53728, accuracy: 0.56250, kappa score: 0.3107, Epoch: -> 7 / 50  Batch Number: -> 4 / 31
# val -> loss: 1.53096, accuracy: 0.58125, kappa score: 0.3320, Epoch: -> 7 / 50  Batch Number: -> 5 / 31
# val -> loss: 1.51984, accuracy: 0.58333, kappa score: 0.3488, Epoch: -> 7 / 50  Batch Number: -> 6 / 31
# val -> loss: 1.54525, accuracy: 0.58929, kappa score: 0.3420, Epoch: -> 7 / 50  Batch Number: -> 7 / 31
# val -> loss: 1.54205, accuracy: 0.57812, kappa score: 0.3116, Epoch: -> 7 / 50  Batch Number: -> 8 / 31
# val -> loss: 1.53083, accuracy: 0.57292, kappa score: 0.3321, Epoch: -> 7 / 50  Batch Number: -> 9 / 31
# val -> loss: 1.51725, accuracy: 0.57188, kappa score: 0.3553, Epoch: -> 7 / 50  Batch Number: -> 10 / 31
# val -> loss: 1.51983, accuracy: 0.56534, kappa score: 0.3496, Epoch: -> 7 / 50  Batch Number: -> 11 / 31
# val -> loss: 1.52933, accuracy: 0.56250, kappa score: 0.3586, Epoch: -> 7 / 50  Batch Number: -> 12 / 31
# val -> loss: 1.51616, accuracy: 0.56731, kappa score: 0.3857, Epoch: -> 7 / 50  Batch Number: -> 13 / 31
# val -> loss: 1.52521, accuracy: 0.56696, kappa score: 0.3699, Epoch: -> 7 / 50  Batch Number: -> 14 / 31
# val -> loss: 1.52710, accuracy: 0.56042, kappa score: 0.3686, Epoch: -> 7 / 50  Batch Number: -> 15 / 31
# val -> loss: 1.52863, accuracy: 0.55859, kappa score: 0.3599, Epoch: -> 7 / 50  Batch Number: -> 16 / 31
# val -> loss: 1.52691, accuracy: 0.56066, kappa score: 0.3523, Epoch: -> 7 / 50  Batch Number: -> 17 / 31
# val -> loss: 1.51157, accuracy: 0.56771, kappa score: 0.3702, Epoch: -> 7 / 50  Batch Number: -> 18 / 31
# val -> loss: 1.50952, accuracy: 0.56743, kappa score: 0.3641, Epoch: -> 7 / 50  Batch Number: -> 19 / 31
# val -> loss: 1.50506, accuracy: 0.56875, kappa score: 0.3681, Epoch: -> 7 / 50  Batch Number: -> 20 / 31
# val -> loss: 1.50190, accuracy: 0.57292, kappa score: 0.3761, Epoch: -> 7 / 50  Batch Number: -> 21 / 31
# val -> loss: 1.50825, accuracy: 0.56818, kappa score: 0.3805, Epoch: -> 7 / 50  Batch Number: -> 22 / 31
# val -> loss: 1.51148, accuracy: 0.56522, kappa score: 0.3837, Epoch: -> 7 / 50  Batch Number: -> 23 / 31
# val -> loss: 1.50950, accuracy: 0.56641, kappa score: 0.3916, Epoch: -> 7 / 50  Batch Number: -> 24 / 31
# val -> loss: 1.50443, accuracy: 0.57125, kappa score: 0.3999, Epoch: -> 7 / 50  Batch Number: -> 25 / 31
# val -> loss: 1.50465, accuracy: 0.57091, kappa score: 0.3962, Epoch: -> 7 / 50  Batch Number: -> 26 / 31
# val -> loss: 1.50131, accuracy: 0.57870, kappa score: 0.4077, Epoch: -> 7 / 50  Batch Number: -> 27 / 31
# val -> loss: 1.50507, accuracy: 0.57589, kappa score: 0.4113, Epoch: -> 7 / 50  Batch Number: -> 28 / 31
# val -> loss: 1.50783, accuracy: 0.57435, kappa score: 0.4007, Epoch: -> 7 / 50  Batch Number: -> 29 / 31
# val -> loss: 1.50108, accuracy: 0.57812, kappa score: 0.3950, Epoch: -> 7 / 50  Batch Number: -> 30 / 31
# val -> loss: 1.50221, accuracy: 0.58274, kappa score: 0.4047, Epoch: -> 7 / 50  Batch Number: -> 31 / 31
# ######################################################################
#
#
#
#
#  New best validation loss: 1.5022123705956247
# Epoch 8 of 50 took 3.589s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 8/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 1.37749, accuracy: 0.62500, kappa score: 0.7521, Epoch: -> 8 / 50  Batch Number: -> 1 / 16
# train -> loss: 1.35848, accuracy: 0.60938, kappa score: 0.7812, Epoch: -> 8 / 50  Batch Number: -> 2 / 16
# train -> loss: 1.39480, accuracy: 0.60417, kappa score: 0.6996, Epoch: -> 8 / 50  Batch Number: -> 3 / 16
# train -> loss: 1.34706, accuracy: 0.61719, kappa score: 0.7371, Epoch: -> 8 / 50  Batch Number: -> 4 / 16
# train -> loss: 1.31635, accuracy: 0.65000, kappa score: 0.7442, Epoch: -> 8 / 50  Batch Number: -> 5 / 16
# train -> loss: 1.29721, accuracy: 0.66667, kappa score: 0.7579, Epoch: -> 8 / 50  Batch Number: -> 6 / 16
# train -> loss: 1.31404, accuracy: 0.66071, kappa score: 0.7510, Epoch: -> 8 / 50  Batch Number: -> 7 / 16
# train -> loss: 1.31613, accuracy: 0.66016, kappa score: 0.7670, Epoch: -> 8 / 50  Batch Number: -> 8 / 16
# train -> loss: 1.32696, accuracy: 0.64236, kappa score: 0.7688, Epoch: -> 8 / 50  Batch Number: -> 9 / 16
# train -> loss: 1.32027, accuracy: 0.64062, kappa score: 0.7836, Epoch: -> 8 / 50  Batch Number: -> 10 / 16
# train -> loss: 1.30631, accuracy: 0.65057, kappa score: 0.7913, Epoch: -> 8 / 50  Batch Number: -> 11 / 16
# train -> loss: 1.30181, accuracy: 0.64844, kappa score: 0.7879, Epoch: -> 8 / 50  Batch Number: -> 12 / 16
# train -> loss: 1.30183, accuracy: 0.65385, kappa score: 0.7987, Epoch: -> 8 / 50  Batch Number: -> 13 / 16
# train -> loss: 1.29183, accuracy: 0.65848, kappa score: 0.8024, Epoch: -> 8 / 50  Batch Number: -> 14 / 16
# train -> loss: 1.28258, accuracy: 0.66875, kappa score: 0.8167, Epoch: -> 8 / 50  Batch Number: -> 15 / 16
# train -> loss: 1.28124, accuracy: 0.66733, kappa score: 0.8176, Epoch: -> 8 / 50  Batch Number: -> 16 / 16
# val -> loss: 1.63920, accuracy: 0.43750, kappa score: 0.0590, Epoch: -> 8 / 50  Batch Number: -> 1 / 31
# val -> loss: 1.52317, accuracy: 0.56250, kappa score: 0.4173, Epoch: -> 8 / 50  Batch Number: -> 2 / 31
# val -> loss: 1.53655, accuracy: 0.52083, kappa score: 0.3635, Epoch: -> 8 / 50  Batch Number: -> 3 / 31
# val -> loss: 1.49454, accuracy: 0.54688, kappa score: 0.3522, Epoch: -> 8 / 50  Batch Number: -> 4 / 31
# val -> loss: 1.46699, accuracy: 0.54375, kappa score: 0.3664, Epoch: -> 8 / 50  Batch Number: -> 5 / 31
# val -> loss: 1.45833, accuracy: 0.56250, kappa score: 0.3626, Epoch: -> 8 / 50  Batch Number: -> 6 / 31
# val -> loss: 1.45717, accuracy: 0.55357, kappa score: 0.3893, Epoch: -> 8 / 50  Batch Number: -> 7 / 31
# val -> loss: 1.43849, accuracy: 0.55078, kappa score: 0.4047, Epoch: -> 8 / 50  Batch Number: -> 8 / 31
# val -> loss: 1.43938, accuracy: 0.56250, kappa score: 0.4026, Epoch: -> 8 / 50  Batch Number: -> 9 / 31
# val -> loss: 1.45372, accuracy: 0.55937, kappa score: 0.4001, Epoch: -> 8 / 50  Batch Number: -> 10 / 31
# val -> loss: 1.44884, accuracy: 0.56250, kappa score: 0.4292, Epoch: -> 8 / 50  Batch Number: -> 11 / 31
# val -> loss: 1.46064, accuracy: 0.55469, kappa score: 0.3669, Epoch: -> 8 / 50  Batch Number: -> 12 / 31
# val -> loss: 1.44501, accuracy: 0.55048, kappa score: 0.3747, Epoch: -> 8 / 50  Batch Number: -> 13 / 31
# val -> loss: 1.44309, accuracy: 0.55357, kappa score: 0.3829, Epoch: -> 8 / 50  Batch Number: -> 14 / 31
# val -> loss: 1.43542, accuracy: 0.55833, kappa score: 0.3960, Epoch: -> 8 / 50  Batch Number: -> 15 / 31
# val -> loss: 1.43418, accuracy: 0.55664, kappa score: 0.3946, Epoch: -> 8 / 50  Batch Number: -> 16 / 31
# val -> loss: 1.42840, accuracy: 0.55699, kappa score: 0.3893, Epoch: -> 8 / 50  Batch Number: -> 17 / 31
# val -> loss: 1.41459, accuracy: 0.57118, kappa score: 0.3968, Epoch: -> 8 / 50  Batch Number: -> 18 / 31
# val -> loss: 1.41807, accuracy: 0.57730, kappa score: 0.4012, Epoch: -> 8 / 50  Batch Number: -> 19 / 31
# val -> loss: 1.41940, accuracy: 0.57656, kappa score: 0.4013, Epoch: -> 8 / 50  Batch Number: -> 20 / 31
# val -> loss: 1.41817, accuracy: 0.58185, kappa score: 0.4003, Epoch: -> 8 / 50  Batch Number: -> 21 / 31
# val -> loss: 1.41245, accuracy: 0.58239, kappa score: 0.4069, Epoch: -> 8 / 50  Batch Number: -> 22 / 31
# val -> loss: 1.42191, accuracy: 0.57745, kappa score: 0.3849, Epoch: -> 8 / 50  Batch Number: -> 23 / 31
# val -> loss: 1.42317, accuracy: 0.57682, kappa score: 0.3866, Epoch: -> 8 / 50  Batch Number: -> 24 / 31
# val -> loss: 1.43061, accuracy: 0.57500, kappa score: 0.3730, Epoch: -> 8 / 50  Batch Number: -> 25 / 31
# val -> loss: 1.43933, accuracy: 0.57572, kappa score: 0.3659, Epoch: -> 8 / 50  Batch Number: -> 26 / 31
# ...
# train -> loss: 0.35224, accuracy: 0.89890, kappa score: 0.9224, Epoch: -> 15 / 50  Batch Number: -> 17 / 47
# train -> loss: 0.36165, accuracy: 0.89583, kappa score: 0.9235, Epoch: -> 15 / 50  Batch Number: -> 18 / 47
# train -> loss: 0.35883, accuracy: 0.89638, kappa score: 0.9204, Epoch: -> 15 / 50  Batch Number: -> 19 / 47
# train -> loss: 0.35835, accuracy: 0.89687, kappa score: 0.9232, Epoch: -> 15 / 50  Batch Number: -> 20 / 47
# train -> loss: 0.35730, accuracy: 0.89435, kappa score: 0.9184, Epoch: -> 15 / 50  Batch Number: -> 21 / 47
# train -> loss: 0.35362, accuracy: 0.89631, kappa score: 0.9164, Epoch: -> 15 / 50  Batch Number: -> 22 / 47
# train -> loss: 0.35200, accuracy: 0.89674, kappa score: 0.9191, Epoch: -> 15 / 50  Batch Number: -> 23 / 47
# train -> loss: 0.35184, accuracy: 0.89714, kappa score: 0.9212, Epoch: -> 15 / 50  Batch Number: -> 24 / 47
# train -> loss: 0.34879, accuracy: 0.89875, kappa score: 0.9202, Epoch: -> 15 / 50  Batch Number: -> 25 / 47
# train -> loss: 0.35014, accuracy: 0.89543, kappa score: 0.9127, Epoch: -> 15 / 50  Batch Number: -> 26 / 47
# train -> loss: 0.34612, accuracy: 0.89699, kappa score: 0.9118, Epoch: -> 15 / 50  Batch Number: -> 27 / 47
# train -> loss: 0.35465, accuracy: 0.89509, kappa score: 0.9103, Epoch: -> 15 / 50  Batch Number: -> 28 / 47
# train -> loss: 0.35861, accuracy: 0.89332, kappa score: 0.9128, Epoch: -> 15 / 50  Batch Number: -> 29 / 47
# train -> loss: 0.36074, accuracy: 0.89271, kappa score: 0.9116, Epoch: -> 15 / 50  Batch Number: -> 30 / 47
# train -> loss: 0.36068, accuracy: 0.89415, kappa score: 0.9127, Epoch: -> 15 / 50  Batch Number: -> 31 / 47
# train -> loss: 0.35853, accuracy: 0.89453, kappa score: 0.9119, Epoch: -> 15 / 50  Batch Number: -> 32 / 47
# train -> loss: 0.35928, accuracy: 0.89489, kappa score: 0.9127, Epoch: -> 15 / 50  Batch Number: -> 33 / 47
# train -> loss: 0.35937, accuracy: 0.89338, kappa score: 0.9122, Epoch: -> 15 / 50  Batch Number: -> 34 / 47
# train -> loss: 0.35797, accuracy: 0.89286, kappa score: 0.9117, Epoch: -> 15 / 50  Batch Number: -> 35 / 47
# train -> loss: 0.35845, accuracy: 0.89149, kappa score: 0.9113, Epoch: -> 15 / 50  Batch Number: -> 36 / 47
# train -> loss: 0.35842, accuracy: 0.89189, kappa score: 0.9133, Epoch: -> 15 / 50  Batch Number: -> 37 / 47
# train -> loss: 0.35492, accuracy: 0.89391, kappa score: 0.9151, Epoch: -> 15 / 50  Batch Number: -> 38 / 47
# train -> loss: 0.35685, accuracy: 0.89263, kappa score: 0.9125, Epoch: -> 15 / 50  Batch Number: -> 39 / 47
# train -> loss: 0.35465, accuracy: 0.89297, kappa score: 0.9144, Epoch: -> 15 / 50  Batch Number: -> 40 / 47
# train -> loss: 0.35600, accuracy: 0.89177, kappa score: 0.9155, Epoch: -> 15 / 50  Batch Number: -> 41 / 47
# train -> loss: 0.35446, accuracy: 0.89211, kappa score: 0.9169, Epoch: -> 15 / 50  Batch Number: -> 42 / 47
# train -> loss: 0.35716, accuracy: 0.89026, kappa score: 0.9174, Epoch: -> 15 / 50  Batch Number: -> 43 / 47
# train -> loss: 0.35385, accuracy: 0.89276, kappa score: 0.9194, Epoch: -> 15 / 50  Batch Number: -> 44 / 47
# train -> loss: 0.35456, accuracy: 0.89236, kappa score: 0.9193, Epoch: -> 15 / 50  Batch Number: -> 45 / 47
# train -> loss: 0.35689, accuracy: 0.88859, kappa score: 0.9180, Epoch: -> 15 / 50  Batch Number: -> 46 / 47
# train -> loss: 0.36458, accuracy: 0.88508, kappa score: 0.9171, Epoch: -> 15 / 50  Batch Number: -> 47 / 47
# val -> loss: 0.85647, accuracy: 0.71875, kappa score: 0.6904, Epoch: -> 15 / 50  Batch Number: -> 1 / 31
# val -> loss: 0.80261, accuracy: 0.75000, kappa score: 0.8282, Epoch: -> 15 / 50  Batch Number: -> 2 / 31
# val -> loss: 0.67312, accuracy: 0.78125, kappa score: 0.8246, Epoch: -> 15 / 50  Batch Number: -> 3 / 31
# val -> loss: 0.64241, accuracy: 0.78906, kappa score: 0.7488, Epoch: -> 15 / 50  Batch Number: -> 4 / 31
# val -> loss: 0.69437, accuracy: 0.76250, kappa score: 0.7139, Epoch: -> 15 / 50  Batch Number: -> 5 / 31
# val -> loss: 0.77584, accuracy: 0.75521, kappa score: 0.6929, Epoch: -> 15 / 50  Batch Number: -> 6 / 31
# val -> loss: 0.76856, accuracy: 0.75446, kappa score: 0.6850, Epoch: -> 15 / 50  Batch Number: -> 7 / 31
# val -> loss: 0.75018, accuracy: 0.75781, kappa score: 0.7132, Epoch: -> 15 / 50  Batch Number: -> 8 / 31
# val -> loss: 0.73268, accuracy: 0.76736, kappa score: 0.7242, Epoch: -> 15 / 50  Batch Number: -> 9 / 31
# val -> loss: 0.72599, accuracy: 0.76875, kappa score: 0.7275, Epoch: -> 15 / 50  Batch Number: -> 10 / 31
# val -> loss: 0.73217, accuracy: 0.76989, kappa score: 0.7367, Epoch: -> 15 / 50  Batch Number: -> 11 / 31
# val -> loss: 0.72972, accuracy: 0.76823, kappa score: 0.7352, Epoch: -> 15 / 50  Batch Number: -> 12 / 31
# val -> loss: 0.72767, accuracy: 0.76923, kappa score: 0.7280, Epoch: -> 15 / 50  Batch Number: -> 13 / 31
# val -> loss: 0.72215, accuracy: 0.77009, kappa score: 0.7360, Epoch: -> 15 / 50  Batch Number: -> 14 / 31
# val -> loss: 0.73784, accuracy: 0.76875, kappa score: 0.7303, Epoch: -> 15 / 50  Batch Number: -> 15 / 31
# val -> loss: 0.72459, accuracy: 0.76758, kappa score: 0.7300, Epoch: -> 15 / 50  Batch Number: -> 16 / 31
# val -> loss: 0.73042, accuracy: 0.76838, kappa score: 0.7396, Epoch: -> 15 / 50  Batch Number: -> 17 / 31
# val -> loss: 0.72954, accuracy: 0.76562, kappa score: 0.7331, Epoch: -> 15 / 50  Batch Number: -> 18 / 31
# val -> loss: 0.72811, accuracy: 0.76480, kappa score: 0.7371, Epoch: -> 15 / 50  Batch Number: -> 19 / 31
# val -> loss: 0.71787, accuracy: 0.76562, kappa score: 0.7409, Epoch: -> 15 / 50  Batch Number: -> 20 / 31
# val -> loss: 0.73019, accuracy: 0.76339, kappa score: 0.7346, Epoch: -> 15 / 50  Batch Number: -> 21 / 31
# val -> loss: 0.73249, accuracy: 0.76136, kappa score: 0.7371, Epoch: -> 15 / 50  Batch Number: -> 22 / 31
# val -> loss: 0.73483, accuracy: 0.75815, kappa score: 0.7399, Epoch: -> 15 / 50  Batch Number: -> 23 / 31
# val -> loss: 0.74136, accuracy: 0.75391, kappa score: 0.7347, Epoch: -> 15 / 50  Batch Number: -> 24 / 31
# val -> loss: 0.73707, accuracy: 0.75375, kappa score: 0.7371, Epoch: -> 15 / 50  Batch Number: -> 25 / 31
# val -> loss: 0.74121, accuracy: 0.75361, kappa score: 0.7344, Epoch: -> 15 / 50  Batch Number: -> 26 / 31
# val -> loss: 0.76266, accuracy: 0.75000, kappa score: 0.7355, Epoch: -> 15 / 50  Batch Number: -> 27 / 31
# val -> loss: 0.75892, accuracy: 0.74888, kappa score: 0.7261, Epoch: -> 15 / 50  Batch Number: -> 28 / 31
# val -> loss: 0.76118, accuracy: 0.74892, kappa score: 0.7261, Epoch: -> 15 / 50  Batch Number: -> 29 / 31
# val -> loss: 0.76215, accuracy: 0.74687, kappa score: 0.7247, Epoch: -> 15 / 50  Batch Number: -> 30 / 31
# val -> loss: 0.77622, accuracy: 0.74621, kappa score: 0.7246, Epoch: -> 15 / 50  Batch Number: -> 31 / 31
# Epoch 16 of 50 took 7.417s ######################################################################
#
#
#
#
#
# ######################################################################
#
#
#
#
#  Epoch 16/49 ----------------------------------------------------------------------
#
#
#
#
#
# train -> loss: 0.23244, accuracy: 0.96875, kappa score: 0.9851, Epoch: -> 16 / 50  Batch Number: -> 1 / 47
# train -> loss: 0.25481, accuracy: 0.95312, kappa score: 0.9624, Epoch: -> 16 / 50  Batch Number: -> 2 / 47
# train -> loss: 0.30170, accuracy: 0.91667, kappa score: 0.9344, Epoch: -> 16 / 50  Batch Number: -> 3 / 47
# train -> loss: 0.27528, accuracy: 0.92188, kappa score: 0.9501, Epoch: -> 16 / 50  Batch Number: -> 4 / 47
# train -> loss: 0.32952, accuracy: 0.90000, kappa score: 0.8958, Epoch: -> 16 / 50  Batch Number: -> 5 / 47
# train -> loss: 0.32161, accuracy: 0.90104, kappa score: 0.8988, Epoch: -> 16 / 50  Batch Number: -> 6 / 47
# train -> loss: 0.30319, accuracy: 0.91071, kappa score: 0.9092, Epoch: -> 16 / 50  Batch Number: -> 7 / 47
# train -> loss: 0.29371, accuracy: 0.92188, kappa score: 0.9213, Epoch: -> 16 / 50  Batch Number: -> 8 / 47
# train -> loss: 0.30752, accuracy: 0.91319, kappa score: 0.9159, Epoch: -> 16 / 50  Batch Number: -> 9 / 47
# train -> loss: 0.30774, accuracy: 0.91563, kappa score: 0.9142, Epoch: -> 16 / 50  Batch Number: -> 10 / 47
# train -> loss: 0.30602, accuracy: 0.91761, kappa score: 0.9181, Epoch: -> 16 / 50  Batch Number: -> 11 / 47
# train -> loss: 0.30586, accuracy: 0.91406, kappa score: 0.9145, Epoch: -> 16 / 50  Batch Number: -> 12 / 47
# train -> loss: 0.31103, accuracy: 0.90625, kappa score: 0.9119, Epoch: -> 16 / 50  Batch Number: -> 13 / 47
# train -> loss: 0.31926, accuracy: 0.90402, kappa score: 0.9123, Epoch: -> 16 / 50  Batch Number: -> 14 / 47
# train -> loss: 0.31739, accuracy: 0.90417, kappa score: 0.9103, Epoch: -> 16 / 50  Batch Number: -> 15 / 47
# train -> loss: 0.32722, accuracy: 0.89648, kappa score: 0.9074, Epoch: -> 16 / 50  Batch Number: -> 16 / 47
# train -> loss: 0.32213, accuracy: 0.90074, kappa score: 0.9107, Epoch: -> 16 / 50  Batch Number: -> 17 / 47
# train -> loss: 0.31459, accuracy: 0.90451, kappa score: 0.9140, Epoch: -> 16 / 50  Batch Number: -> 18 / 47
# train -> loss: 0.31857, accuracy: 0.90132, kappa score: 0.9092, Epoch: -> 16 / 50  Batch Number: -> 19 / 47
# train -> loss: 0.31768, accuracy: 0.90469, kappa score: 0.9136, Epoch: -> 16 / 50  Batch Number: -> 20 / 47
# train -> loss: 0.31789, accuracy: 0.90476, kappa score: 0.9160, Epoch: -> 16 / 50  Batch Number: -> 21 / 47
# train -> loss: 0.31706, accuracy: 0.90483, kappa score: 0.9163, Epoch: -> 16 / 50  Batch Number: -> 22 / 47
# train -> loss: 0.32570, accuracy: 0.90082, kappa score: 0.9150, Epoch: -> 16 / 50  Batch Number: -> 23 / 47
# train -> loss: 0.32304, accuracy: 0.90234, kappa score: 0.9179, Epoch: -> 16 / 50  Batch Number: -> 24 / 47
# train -> loss: 0.32819, accuracy: 0.90000, kappa score: 0.9187, Epoch: -> 16 / 50  Batch Number: -> 25 / 47
# train -> loss: 0.32862, accuracy: 0.90024, kappa score: 0.9186, Epoch: -> 16 / 50  Batch Number: -> 26 / 47
# train -> loss: 0.32973, accuracy: 0.89931, kappa score: 0.9173, Epoch: -> 16 / 50  Batch Number: -> 27 / 47
# train -> loss: 0.32581, accuracy: 0.89955, kappa score: 0.9191, Epoch: -> 16 / 50  Batch Number: -> 28 / 47
# train -> loss: 0.32872, accuracy: 0.89763, kappa score: 0.9181, Epoch: -> 16 / 50  Batch Number: -> 29 / 47
# train -> loss: 0.33071, accuracy: 0.89792, kappa score: 0.9172, Epoch: -> 16 / 50  Batch Number: -> 30 / 47
# train -> loss: 0.33901, accuracy: 0.89516, kappa score: 0.9168, Epoch: -> 16 / 50  Batch Number: -> 31 / 47
# train -> loss: 0.34172, accuracy: 0.89160, kappa score: 0.9145, Epoch: -> 16 / 50  Batch Number: -> 32 / 47
# train -> loss: 0.34010, accuracy: 0.89394, kappa score: 0.9169, Epoch: -> 16 / 50  Batch Number: -> 33 / 47
# train -> loss: 0.34377, accuracy: 0.89246, kappa score: 0.9144, Epoch: -> 16 / 50  Batch Number: -> 34 / 47
# train -> loss: 0.34401, accuracy: 0.89107, kappa score: 0.9130, Epoch: -> 16 / 50  Batch Number: -> 35 / 47
# train -> loss: 0.34070, accuracy: 0.89236, kappa score: 0.9137, Epoch: -> 16 / 50  Batch Number: -> 36 / 47
# train -> loss: 0.33735, accuracy: 0.89358, kappa score: 0.9141, Epoch: -> 16 / 50  Batch Number: -> 37 / 47
# train -> loss: 0.33603, accuracy: 0.89391, kappa score: 0.9155, Epoch: -> 16 / 50  Batch Number: -> 38 / 47
# train -> loss: 0.33263, accuracy: 0.89663, kappa score: 0.9168, Epoch: -> 16 / 50  Batch Number: -> 39 / 47
# train -> loss: 0.33029, accuracy: 0.89844, kappa score: 0.9185, Epoch: -> 16 / 50  Batch Number: -> 40 / 47
# train -> loss: 0.33138, accuracy: 0.89787, kappa score: 0.9192, Epoch: -> 16 / 50  Batch Number: -> 41 / 47
# train -> loss: 0.33548, accuracy: 0.89658, kappa score: 0.9156, Epoch: -> 16 / 50  Batch Number: -> 42 / 47
# train -> loss: 0.33649, accuracy: 0.89680, kappa score: 0.9140, Epoch: -> 16 / 50  Batch Number: -> 43 / 47
# train -> loss: 0.34197, accuracy: 0.89418, kappa score: 0.9137, Epoch: -> 16 / 50  Batch Number: -> 44 / 47
# train -> loss: 0.34131, accuracy: 0.89375, kappa score: 0.9146, Epoch: -> 16 / 50  Batch Number: -> 45 / 47
# train -> loss: 0.33997, accuracy: 0.89402, kappa score: 0.9156, Epoch: -> 16 / 50  Batch Number: -> 46 / 47
# train -> loss: 0.33718, accuracy: 0.89516, kappa score: 0.9166, Epoch: -> 16 / 50  Batch Number: -> 47 / 47
# val -> loss: 1.06029, accuracy: 0.62500, kappa score: 0.4310, Epoch: -> 16 / 50  Batch Number: -> 1 / 31
# val -> loss: 0.83195, accuracy: 0.71875, kappa score: 0.6839, Epoch: -> 16 / 50  Batch Number: -> 2 / 31
# val -> loss: 0.95034, accuracy: 0.70833, kappa score: 0.6531, Epoch: -> 16 / 50  Batch Number: -> 3 / 31
# val -> loss: 0.87261, accuracy: 0.73438, kappa score: 0.6953, Epoch: -> 16 / 50  Batch Number: -> 4 / 31
# val -> loss: 0.83582, accuracy: 0.75625, kappa score: 0.7213, Epoch: -> 16 / 50  Batch Number: -> 5 / 31
# val -> loss: 0.86179, accuracy: 0.75521, kappa score: 0.7503, Epoch: -> 16 / 50  Batch Number: -> 6 / 31
# val -> loss: 0.84913, accuracy: 0.76339, kappa score: 0.7631, Epoch: -> 16 / 50  Batch Number: -> 7 / 31
# val -> loss: 0.83362, accuracy: 0.76172, kappa score: 0.7598, Epoch: -> 16 / 50  Batch Number: -> 8 / 31
# val -> loss: 0.84698, accuracy: 0.75694, kappa score: 0.7629, Epoch: -> 16 / 50  Batch Number: -> 9 / 31
# val -> loss: 0.83829, accuracy: 0.75625, kappa score: 0.7702, Epoch: -> 16 / 50  Batch Number: -> 10 / 31
# val -> loss: 0.81953, accuracy: 0.76136, kappa score: 0.7770, Epoch: -> 16 / 50  Batch Number: -> 11 / 31
# val -> loss: 0.82472, accuracy: 0.75260, kappa score: 0.7580, Epoch: -> 16 / 50  Batch Number: -> 12 / 31
# val -> loss: 0.82325, accuracy: 0.75240, kappa score: 0.7501, Epoch: -> 16 / 50  Batch Number: -> 13 / 31
# val -> loss: 0.81327, accuracy: 0.75446, kappa score: 0.7417, Epoch: -> 16 / 50  Batch Number: -> 14 / 31
# val -> loss: 0.80017, accuracy: 0.76042, kappa score: 0.7315, Epoch: -> 16 / 50  Batch Number: -> 15 / 31
# val -> loss: 0.78303, accuracy: 0.76172, kappa score: 0.7471, Epoch: -> 16 / 50  Batch Number: -> 16 / 31
# val -> loss: 0.78326, accuracy: 0.76287, kappa score: 0.7451, Epoch: -> 16 / 50  Batch Number: -> 17 / 31
# val -> loss: 0.78069, accuracy: 0.75868, kappa score: 0.7402, Epoch: -> 16 / 50  Batch Number: -> 18 / 31
# val -> loss: 0.76997, accuracy: 0.76151, kappa score: 0.7448, Epoch: -> 16 / 50  Batch Number: -> 19 / 31
# val -> loss: 0.76667, accuracy: 0.76406, kappa score: 0.7344, Epoch: -> 16 / 50  Batch Number: -> 20 / 31
# val -> loss: 0.75614, accuracy: 0.76935, kappa score: 0.7344, Epoch: -> 16 / 50  Batch Number: -> 21 / 31
# val -> loss: 0.78058, accuracy: 0.76562, kappa score: 0.7362, Epoch: -> 16 / 50  Batch Number: -> 22 / 31
# val -> loss: 0.80182, accuracy: 0.75951, kappa score: 0.7218, Epoch: -> 16 / 50  Batch Number: -> 23 / 31
# val -> loss: 0.78424, accuracy: 0.76302, kappa score: 0.7258, Epoch: -> 16 / 50  Batch Number: -> 24 / 31
# val -> loss: 0.78917, accuracy: 0.76000, kappa score: 0.7293, Epoch: -> 16 / 50  Batch Number: -> 25 / 31
# val -> loss: 0.78052, accuracy: 0.76082, kappa score: 0.7321, Epoch: -> 16 / 50  Batch Number: -> 26 / 31
# val -> loss: 0.79185, accuracy: 0.75579, kappa score: 0.7222, Epoch: -> 16 / 50  Batch Number: -> 27 / 31
# val -> loss: 0.78707, accuracy: 0.75558, kappa score: 0.7280, Epoch: -> 16 / 50  Batch Number: -> 28 / 31
# val -> loss: 0.79463, accuracy: 0.75323, kappa score: 0.7270, Epoch: -> 16 / 50  Batch Number: -> 29 / 31
# val -> loss: 0.80557, accuracy: 0.75104, kappa score: 0.7251, Epoch: -> 16 / 50  Batch Number: -> 30 / 31
# val -> loss: 0.78927, accuracy: 0.75531, kappa score: 0.7262, Epoch: -> 16 / 50  Batch Number: -> 31 / 31
# Epoch 17 of 50 took 6.212s ######################################################################
#
#
#
#
#
# Training complete in 1m 56s
# Best val loss: 0.670701
# Plot saved in --> /content/drive/MyDrive/Tesi_Magistrale/DATA/Giulio_offset_relabel/day1/Rep_Train_Trials//Rep_1_2_3/Cross_rep/Plot/Cross_rep_wnd_200_zero_to_one_sub_rect_True_ang_5_day1.png
# Conf_Matrix saved in -->  /content/drive/MyDrive/Tesi_Magistrale/DATA/Giulio_offset_relabel/day1/Rep_Train_Trials//Rep_1_2_3/Cross_rep/Conf_Matrix/Cross_rep_N_wnd_200_zero_to_one_sub_rect_True_ang_5_day1.png
# Results Saved in -> /content/drive/MyDrive/Tesi_Magistrale/DATA/Giulio_offset_relabel/day1/Rep_Train_Trials//Rep_1_2_3//Cross_rep/Evals.csv
